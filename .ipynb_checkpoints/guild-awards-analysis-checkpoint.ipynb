# %% [markdown]
# # Guild Awards Analysis
#
# <ul>
# <li><a href="#garothi">Garothi</a></li>
# <li><a href="#felhounds">Felhounds</a></li>
# <li><a href="#highc">High Command</a>
#     <ul>
#         <li><a href="#highc-dispell">Dispels</a></li>
#         <li><a href="#highc-bombs">Least Bomb Damage</a></li>
#     </ul></li>
# <li><a href="#portalk">Portal Keeper</a>
#     <ul>
#         <li><a href="#portalk-interupts">Interupts</a></li>
#         <li><a href="#portalk-adds">Add Damage</a></li>
#     </ul></li>
# <li><a href="#eonar">Eonar</a>
# <li><a href="#imonar">Imonar</a>
#     <ul>
#         <li><a href="#imonar-orbs">Least Conflag Damage</a></li>
#         <li><a href="#imonar-dispels">Dispels</a></li>
#     </ul></li>
# <li><a href="#kennyg">Kin'Garoth</a>
# <li><a href="#vari">Varimathras</a>
# <li><a href="#coven">Coven</a>
#     <ul>
#         <li><a href="#coven-glare">Least Cosmic Glare Damage</a></li>
#         <li><a href="#coven-blades">Least Shadow Blades Damage</a></li>
#         <li><a href="#coven-storm">Least Storm Damage</a></li>
#         <li><a href="#coven-cc">Most CC Casts</a></li>
#     </ul></li>
# <li><a href="#agg">Aggramar</a>
#     <ul>
#         <li><a href="#agg-blaze">Least Blaze Damage</a></li>
#         <li><a href="#agg-rend">Most Rend Hits</a></li>
#     </ul></li>
# <li><a href="#argus">Argus</a>
#     <ul>
#         <li><a href="#argus-fear">Least Crushing Fear Damage</a></li>
#         <li><a href="#argus-rage">Least Unleash Rage Damage</a></li>
#         <li><a href="#argus-blight">Least Soulblight & Death Fog Damage</a></li>
#         <li><a href="#argus-scythe">Least Scythe Damage</a></li>
#         <li><a href="#argus-orbs">Most Damage Done to Orbs</a></li>
#     </ul></li>
# <li><a href="#overall">Overall</a>
#     <ul>
#         <li><a href="#imonar-orbs">Least Conflag Damage</a></li>
#         <li><a href="#imonar-dispels">Dispels</a></li>
#     </ul></li>
# </ul>

# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import seaborn as sns
import warcraft_logs_fn as wl
import log_analysis as la
# %matplotlib inline

# %%
api_key = '0a60df4bb184d6c614fb96e0126bd407'

# %% [markdown]
# Import log details

# %%
df = pd.read_csv('master_list.csv', encoding="iso-8859-1")
df.head()
# Out:
#              log_id     log_start       log_end  pull_id  pull_start  \
# 0  1dApmwBHyQ2vcVTF  1.526609e+12  1.526619e+12        1     1397463
# 1  1dApmwBHyQ2vcVTF  1.526609e+12  1.526619e+12        1     1397463
# 2  1dApmwBHyQ2vcVTF  1.526609e+12  1.526619e+12        1     1397463
# 3  1dApmwBHyQ2vcVTF  1.526609e+12  1.526619e+12        1     1397463
# 4  1dApmwBHyQ2vcVTF  1.526609e+12  1.526619e+12        1     1397463
#
#    pull_end  boss_id          boss_name   kill   player_name
# 0   1482607     2092  Argus the Unmaker  False        Petrol
# 1   1482607     2092  Argus the Unmaker  False  Radiantldeal
# 2   1482607     2092  Argus the Unmaker  False   Shallowfall
# 3   1482607     2092  Argus the Unmaker  False       Acturus
# 4   1482607     2092  Argus the Unmaker  False          Tawñ

# %%
df.log_id.nunique()
# Out:
# 93

# %%
df.boss_name.unique()
# Out:
# array(['Argus the Unmaker', 'Felhounds of Sargeras', 'Varimathras',
#        'The Coven of Shivarra', 'Aggramar', 'Garothi Worldbreaker',
#        'Antoran High Command', 'Portal Keeper Hasabel',
#        'The Defense of Eonar', "Kin'garoth", 'Imonar the Soulhunter'],
#       dtype=object)

# %%
df.player_name.unique()
# Out:
# array(['Petrol', 'Radiantldeal', 'Shallowfall', 'Acturus', 'Tawñ',
#        'Divanance', 'Tinytiki', 'Metonymy', 'Mythrose', 'Uuglei', 'Earrl',
#        'Cagliostro', 'Ayriea', 'Illestra', 'Daffy', 'Stradivarus',
#        'Vaelyra', 'Brian', 'Psychodruid', 'Shadowbaine', 'Velryssa',
#        'Thebadlock', 'Cinzia', 'Elzam', 'Znoch', 'Kamer', 'Brianmurican',
#        'Googboog', 'Pulsè', 'Kyarrix', 'Zephyyra', 'Future', 'Èllipses',
#        'Bryiah', 'Au', 'Eleint', 'Shaami', 'Velsummers', 'Verle',
#        'Katanescence', 'Undertakerop', 'Demonhoney', 'Yoked'],
#       dtype=object)

# %% [markdown]
# Import player details

# %%
player_names = pd.read_csv('player_list.csv', encoding='iso-8859-1')
player_names.head()
# Out:
#      player primary_role           alt  tier_end  tier_start  start_date
# 0   Vaelyra       damage           NaN      True        True         NaN
# 1  Metonymy       damage           NaN      True        True         NaN
# 2     Brian       damage  Brianmurican      True        True         NaN
# 3    Shaami       healer           NaN      True       False  2018-06-12
# 4    Petrol       damage           NaN      True        True         NaN

# %%
player_names.player.unique()
# Out:
# array(['Vaelyra', 'Metonymy', 'Brian', 'Shaami', 'Petrol', 'Ayriea',
#        'Stradivarus', 'Uuglei', 'Earrl', 'Illestra', 'Kamer',
#        'Cagliostro', 'Shallowfall', 'Tawñ', 'Divanance', 'Psychodruid',
#        'Katanescence', 'Velsummers', 'Radiantldeal', 'Mythrose',
#        'Shadowbaine', 'Acturus', 'Velryssa', 'Eleint', 'Tinytiki',
#        'Daffy', 'Demonhoney', 'Èllipses', 'Au', 'Future', 'Pulsè',
#        'Undertakerop', 'Kyarrix', 'Yoked', 'Bryiah', 'Zephyyra',
#        'Googboog', 'Cinzia'], dtype=object)

# %% [markdown]
# <a id='garothi'></a>
# ## Garothi

# %% [markdown]
# Spell IDs
# - Annihilation: 244761
# - Annihilation: 244762
# - Annihilation: 246971

# %% [markdown]
# ### Annihilation hits

# %% [markdown]
# #### Query Tests

# %%
damage = requests.get('https://www.warcraftlogs.com:443/v1/report/tables/damage-taken/mLRnbfNQ2MT74391?end=4366072&by=source&abilityid=244761&encounter=2076&api_key=' + api_key)
details = damage.json()
details
# Out:
# {'entries': [{'name': 'Radiantldeal',
#    'id': 6,
#    'guid': 132717098,
#    'type': 'Priest',
#    'itemLevel': 949,
#    'icon': 'Priest-Holy',
#    'total': 46380977,
#    'activeTime': 0,
#    'activeTimeReduced': 0,
#    'overheal': -46380977,
#    'damageAbilities': [],
#    'sources': [{'name': 'Annihilator', 'total': 46380977, 'type': 'NPC'}],
#    'talents': [{'name': 'Enlightenment',
#      'guid': 193155,
#      'type': 1,
#      'abilityIcon': 'spell_arcane_mindmastery.jpg'},
#     {'name': 'Angelic Feather',
#      'guid': 121536,
#      'type': 2,
#      'abilityIcon': 'ability_priest_angelicfeather.jpg'},
#     {'name': 'Afterlife',
#      'guid': 196707,
#      'type': 1,
#      'abilityIcon': 'inv_enchant_essencemagiclarge.jpg'},
#     {'name': 'Light of the Naaru',
#      'guid': 196985,
#      'type': 1,
#      'abilityIcon': 'inv_pet_naaru.jpg'},
#     {'name': 'Piety',
#      'guid': 197034,
#      'type': 1,
# ...

# %%
details.keys()
# Out:
# dict_keys(['entries', 'totalTime', 'logVersion'])

# %%
details['entries'][0].keys()
# Out:
# dict_keys(['name', 'id', 'guid', 'type', 'itemLevel', 'icon', 'total', 'activeTime', 'activeTimeReduced', 'overheal', 'damageAbilities', 'sources', 'talents', 'gear', 'uses', 'hitCount', 'tickCount', 'tickMissCount', 'missCount', 'multistrikeHitCount', 'multistrikeTickCount', 'multistrikeMissCount', 'multistrikeTickMissCount', 'critHitCount', 'critTickCount', 'hitdetails', 'multistrikedetails', 'missdetails', 'multistrikemissdetails'])

# %%
details['entries'][0]['hitCount']
# Out:
# 21

# %%
details['entries'][0]['total']
# Out:
# 46380977

# %% [markdown]
# #### Create function

# %% [markdown]
# Get logs for boss

# %%
df[df.boss_name == 'Garothi Worldbreaker'].log_id.unique()
# Out:
# array(['2c6whdrGDkKHP7Nv', '4AP62tL1NzjfFWd7', '7H6FtpVr9c4xaW8L',
#        '9kMHLbPGKNFn6dJ3', '9rzLcb8w6CWJAgfn', 'A3JdRnmp4P9YVvZ1',
#        'a7Pqm1ZvfWhVY4Hn', 'aw1md6gP9RyGDX3z', 'bvV2YFyrRQdpJ6xf',
#        'dZfYj6ynTA21WDxa', 'gbTRy3GhdN9CY46r', 'hDTjXr8H3FqtNLk1',
#        'jLawcr3MKX4k12dC', 'mLRnbfNQ2MT74391', 'Q47z3KZ29tfGxCDW',
#        'TJPXdVcafZ49tLGm', 'wXkPMTryhbtWa2mD', 'YGa62MVkATCdL4Zp',
#        'zapjvhB4HkRg2Ycw'], dtype=object)

# %%
def get_logs(df, boss_name=None):
    if boss_name is None:
        logs = df['log_id'].unique()
    else:
        logs = df[df.boss_id == boss_name].log_id.unique()
    
    return logs

# %%
def create_link(api_key, log_type, log_df, log, spell_id=None, boss_id=None):
    # Create link components
    end = log_df[log_df['log_id'] == log].pull_end.max()
    link_start = 'https://www.warcraftlogs.com:443/v1/report/tables/'
    end_info = '?end=' + str(end) + '&'
    by_info = 'by=source&'
    ability_info = 'abilityid=' + str(spell_id) + '&'
    if spell_id is None:
        ability_info = ''
    boss_info = 'encounter=' + str(boss_id) + '&'
    if boss_id is None:
        boss_info = ''
    link_end = 'difficulty=5&api_key=' + api_key
    
    # Create link
    link = link_start + log_type + '/' + log + end_info + by_info + ability_info + boss_info + link_end
    return link

# %%
def get_details(link):
    event = requests.get(link)
    return event.json()

# %%
def drop_spell_name(df, spell_name):
    if spell_name is None:
        df.drop('spell_name', axis=1, inplace=True)

# %%
def drop_description(df, description):
    if description is None:
        df.drop('description', axis=1, inplace=True)

# %%
def damage_taken(api_key, log_df, spell_id, spell_name=None, boss_id=None):
    df_list = []
    logs = get_logs(log_df, boss_id)
    for log in logs:
        print('Collecting details for log', log)
        
        # Complete query
        link = create_link(api_key, 'damage-taken', log_df, log, spell_id, boss_id)
        details = get_details(link)
        
        # Get player info
        for player in details['entries']:
            name = player['name']
            print('Player added:', name)
            hits = player['hitCount']
            damage = player['total']
            df_list.append({
                'log_id': log, 
                'spell_id': spell_id,
                'spell_name': spell_name,
                'player': name,
                'hits': hits,
                'damage_taken': damage
            })
        
    # Create dataframe
    df = pd.DataFrame(df_list, columns=['log_id', 'spell_id', 'spell_name', 'player', 'hits', 'damage_taken'])
    drop_spell_name(df, spell_name)
        
    return df

# %%
test = df.query('log_id == "mLRnbfNQ2MT74391"')

# %%
get_logs(df, 2076)
# Out:
# array(['2c6whdrGDkKHP7Nv', '4AP62tL1NzjfFWd7', '7H6FtpVr9c4xaW8L',
#        '9kMHLbPGKNFn6dJ3', '9rzLcb8w6CWJAgfn', 'A3JdRnmp4P9YVvZ1',
#        'a7Pqm1ZvfWhVY4Hn', 'aw1md6gP9RyGDX3z', 'bvV2YFyrRQdpJ6xf',
#        'dZfYj6ynTA21WDxa', 'gbTRy3GhdN9CY46r', 'hDTjXr8H3FqtNLk1',
#        'jLawcr3MKX4k12dC', 'mLRnbfNQ2MT74391', 'Q47z3KZ29tfGxCDW',
#        'TJPXdVcafZ49tLGm', 'wXkPMTryhbtWa2mD', 'YGa62MVkATCdL4Zp',
#        'zapjvhB4HkRg2Ycw'], dtype=object)

# %%
damage = damage_taken(api_key, test, 244761, 'annihilation', boss_id=2076)
# Out:
# ['mLRnbfNQ2MT74391']
# ...
# Player added: Shadowbaine
# Player added: Tinytiki
# Player added: Shallowfall
# Player added: Brianmurican
# Player added: Elzam
# Player added: Vaelyra
# Player added: Velryssa
# Player added: Radiantldeal
# Player added: Acturus
# Player added: Metonymy
# Player added: Illestra
# Player added: Znoch
# Player added: Ayriea
# Player added: Googboog
# Player added: Au
# Player added: Mythrose
# Player added: Divanance
# Player added: Petrol
# Player added: Psychodruid

# %% [markdown]
# #### Get damage info

# %% [markdown]
# Spell ID: 244761

# %%
spell_id_244761 = wl.damage_taken(api_key, df, 244761, 'annihilation', boss_id=2076)
# Out:
# ...
# Player added: Au
# Player added: Petrol
# Player added: Ayriea
# Player added: Vaelyra
# Player added: Shadowbaine
# Player added: Kyarrix
# Player added: Illestra
# Player added: Metonymy
# Player added: Mythrose
# Player added: Cagliostro
# Player added: Acturus
# Player added: Zephyyra
# Player added: Shallowfall
# Player added: Radiantldeal
# Player added: Znoch
# Player added: Velryssa
# Player added: Tinytiki
# Player added: Brian
# ...
# Player added: Tinytiki
# Player added: Acturus
# Player added: Mythrose
# Player added: Radiantldeal
# Player added: Illestra
# Player added: Cagliostro
# Player added: Zephyyra
# Player added: Velryssa
# Player added: Vaelyra
# Player added: Thebadlock
# Player added: Shallowfall
# Player added: Znoch
# Player added: Kamer
# Player added: Brianmurican
# Player added: Metonymy
# Player added: Ayriea
# Player added: Petrol
# Player added: Au
# ...
# Player added: Mythrose
# Player added: Radiantldeal
# Player added: Zephyyra
# Player added: Vaelyra
# ...

# %%
spell_id_244761.head()
# Out:
#              log_id  spell_id    spell_name       player  hits  damage_taken
# 0  2c6whdrGDkKHP7Nv    244761  annihilation           Au     2       1648634
# 1  2c6whdrGDkKHP7Nv    244761  annihilation       Petrol     5       8784498
# 2  2c6whdrGDkKHP7Nv    244761  annihilation       Ayriea     5       9406290
# 3  2c6whdrGDkKHP7Nv    244761  annihilation      Vaelyra     5       5501465
# 4  2c6whdrGDkKHP7Nv    244761  annihilation  Shadowbaine     4       6476690

# %%
spell_id_244761.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 346 entries, 0 to 345
# Data columns (total 6 columns):
# log_id          346 non-null object
# spell_id        346 non-null int64
# spell_name      346 non-null object
# player          346 non-null object
# hits            346 non-null int64
# damage_taken    346 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 16.3+ KB

# %% [markdown]
# Spell ID: 244762

# %%
spell_id_244762 = wl.damage_taken(api_key, df, 244762, 'annihilation', boss_id=2076)
# Out:
# ...
# Player added: Illestra
# Player added: Cagliostro
# Player added: Divanance
# Player added: Mythrose
# Player added: Petrol
# Player added: Earrl
# Player added: Shallowfall
# Player added: Radiantldeal
# Player added: Zephyyra
# Player added: Shadowbaine
# Player added: Metonymy
# Player added: Ayriea
# Player added: Vaelyra
# Player added: Znoch
# Player added: Brian
# Player added: Acturus
# Player added: Tinytiki
# Player added: Velryssa
# Player added: Au
# Player added: Kyarrix
# ...
# Player added: Brian
# Player added: Radiantldeal
# Player added: Au
# Player added: Illestra
# Player added: Èllipses
# Player added: Divanance
# Player added: Stradivarus
# Player added: Earrl
# Player added: Petrol
# Player added: Shallowfall
# Player added: Vaelyra
# Player added: Cagliostro
# Player added: Metonymy
# Player added: Verle
# Player added: Acturus
# Player added: Zephyyra
# ...
# Player added: Tinytiki
# Player added: Ayriea
# Player added: Metonymy
# Player added: Psychodruid
# ...

# %%
spell_id_244762.head()
# Out:
#              log_id  spell_id    spell_name      player  hits  damage_taken
# 0  2c6whdrGDkKHP7Nv    244762  annihilation    Illestra     2       4367863
# 1  2c6whdrGDkKHP7Nv    244762  annihilation  Cagliostro     2       5079262
# 2  2c6whdrGDkKHP7Nv    244762  annihilation   Divanance     2       3938244
# 3  2c6whdrGDkKHP7Nv    244762  annihilation    Mythrose     2       4970041
# 4  2c6whdrGDkKHP7Nv    244762  annihilation      Petrol     2       5376126

# %%
spell_id_244762.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 6 columns):
# log_id          295 non-null object
# spell_id        295 non-null int64
# spell_name      295 non-null object
# player          295 non-null object
# hits            295 non-null int64
# damage_taken    295 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 13.9+ KB

# %% [markdown]
# Spell ID: 246971

# %%
spell_id_246971 = wl.damage_taken(api_key, df, 246971, 'annihilation', boss_id=2076)
# Out:
# ...
# Player added: Znoch
# Player added: Radiantldeal
# Player added: Shallowfall
# Player added: Velryssa
# Player added: Ayriea
# Player added: Mythrose
# Player added: Metonymy
# Player added: Acturus
# Player added: Tinytiki
# Player added: Vaelyra
# Player added: Illestra
# Player added: Cagliostro
# Player added: Shadowbaine
# Player added: Zephyyra
# Player added: Au
# Player added: Petrol
# ...
# Player added: Brianmurican
# Player added: Metonymy
# Player added: Mythrose
# Player added: Zephyyra
# Player added: Shallowfall
# Player added: Acturus
# Player added: Petrol
# Player added: Illestra
# Player added: Vaelyra
# Player added: Kamer
# Player added: Velryssa
# Player added: Radiantldeal
# Player added: Ayriea
# Player added: Au
# Player added: Tinytiki
# Player added: Cagliostro
# Player added: Thebadlock
# Player added: Znoch
# ...
# Player added: Cagliostro
# Player added: Illestra
# Player added: Acturus
# Player added: Vaelyra
# Player added: Brian
# Player added: Shallowfall
# ...

# %%
spell_id_246971.head()
# Out:
#              log_id  spell_id    spell_name        player  hits  damage_taken
# 0  2c6whdrGDkKHP7Nv    246971  annihilation         Znoch     1       5206962
# 1  2c6whdrGDkKHP7Nv    246971  annihilation  Radiantldeal     1        631287
# 2  2c6whdrGDkKHP7Nv    246971  annihilation   Shallowfall     1        746777
# 3  2c6whdrGDkKHP7Nv    246971  annihilation      Velryssa     1        925309
# 4  2c6whdrGDkKHP7Nv    246971  annihilation        Ayriea     2       3539668

# %%
spell_id_246971.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319 entries, 0 to 318
# Data columns (total 6 columns):
# log_id          319 non-null object
# spell_id        319 non-null int64
# spell_name      319 non-null object
# player          319 non-null object
# hits            319 non-null int64
# damage_taken    319 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 15.0+ KB

# %% [markdown]
# Combine to single dataframe

# %%
annihilation = pd.concat([spell_id_244761, spell_id_244762, spell_id_246971])
annihilation.head()
# Out:
#              log_id  spell_id    spell_name       player  hits  damage_taken
# 0  2c6whdrGDkKHP7Nv    244761  annihilation           Au     2       1648634
# 1  2c6whdrGDkKHP7Nv    244761  annihilation       Petrol     5       8784498
# 2  2c6whdrGDkKHP7Nv    244761  annihilation       Ayriea     5       9406290
# 3  2c6whdrGDkKHP7Nv    244761  annihilation      Vaelyra     5       5501465
# 4  2c6whdrGDkKHP7Nv    244761  annihilation  Shadowbaine     4       6476690

# %%
annihilation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 960 entries, 0 to 318
# Data columns (total 6 columns):
# log_id          960 non-null object
# spell_id        960 non-null int64
# spell_name      960 non-null object
# player          960 non-null object
# hits            960 non-null int64
# damage_taken    960 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 52.5+ KB

# %% [markdown]
# Save basic pull info

# %%
annihilation.to_csv('guild_awards/garothi_annihilation_data.csv', encoding='iso-8859-1', index=False)

# %% [markdown]
# Clean data

# %%
annihilation = pd.read_csv('guild_awards/garothi_annihilation_data.csv', encoding='iso-8859-1')

# %%
ann_hits = la.clean_damage_fight_count(annihilation, df, player_names, 2076)
ann_hits.head()
# Out:
#     player  hits  damage_taken  fight_count primary_role
# 0  Acturus   244     368589259           36       healer
# 1       Au   147     206876481           21       damage
# 2   Ayriea   207     397335280           28       damage
# 3    Brian   277     464337254           36       damage
# 4   Bryiah    73     102090876           11       damage

# %%
ann_hits = la.find_hit_order(ann_hits, 25, least=False)
ann_hits
# Out:
#           player  hits  damage_taken  fight_count primary_role    av_hit
# 12      Illestra   311     548153569           37       healer  8.405405
# 17      Mythrose   305     593540574           37       healer  8.243243
# 21  Radiantldeal   295     584820588           36       healer  8.194444
# 18        Petrol   297     623509996           37       damage  8.027027
# 23   Shadowbaine   276     516426915           35       damage  7.885714
# 16      Metonymy   277     623850775           36       damage  7.694444
# 3          Brian   277     464337254           36       damage  7.694444
# 10        Future   268     520370906           35       damage  7.657143
# 2         Ayriea   207     397335280           28       damage  7.392857
# 30       Vaelyra   258     445560036           35       damage  7.371429
# 24   Shallowfall   235     326281326           34       damage  6.911765
# 27      Tinytiki   186     202104880           27       damage  6.888889
# ...

# %%
sns.distplot(ann_hits.av_hit, kde=False);
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(ann_hits, col='primary_role').map(sns.distplot, "av_hit");
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
ann_hits.to_csv('guild_awards/garothi_annihilation_hits.csv', encoding='iso-8859-1', index=False)

# %% [markdown]
# <a id='felhounds'></a>
# ## Felhounds

# %% [markdown]
# - Spell ID: 244473
# - Boss ID: 2074

# %%
enflamed = wl.damage_taken(api_key, df, 244473, 'enflamed', 2074)
# Out:
# ...
# Player added: Kamer
# Player added: Petrol
# Player added: Acturus
# Player added: Shallowfall
# Player added: Znoch
# Player added: Cinzia
# Player added: Brianmurican
# Player added: Psychodruid
# Player added: Vaelyra
# Player added: Earrl
# Player added: Mythrose
# Player added: Velryssa
# Player added: Elzam
# Player added: Divanance
# Player added: Metonymy
# Player added: Googboog
# Player added: Thebadlock
# Player added: Illestra
# Player added: Ayriea
# Player added: Radiantldeal
# ...
# Player added: Brian
# Player added: Znoch
# Player added: Metonymy
# Player added: Kyarrix
# Player added: Zephyyra
# Player added: Earrl
# Player added: Ayriea
# Player added: Shadowbaine
# Player added: Illestra
# Player added: Au
# Player added: Petrol
# Player added: Cagliostro
# Player added: Vaelyra
# Player added: Shallowfall
# Player added: Radiantldeal
# Player added: Acturus
# Player added: Divanance
# Player added: Mythrose
# Player added: Tinytiki
# Player added: Velryssa
# ...

# %%
enflamed.head()
# Out:
#              log_id  spell_id spell_name        player  hits  damage_taken
# 0  1MJK9vG4qAkzWBbg    244473   enflamed    Thebadlock     8       9313567
# 1  1MJK9vG4qAkzWBbg    244473   enflamed  Brianmurican     8      10496935
# 2  1MJK9vG4qAkzWBbg    244473   enflamed  Radiantldeal    12      14649185
# 3  1MJK9vG4qAkzWBbg    244473   enflamed      Velryssa     7       8912065
# 4  1MJK9vG4qAkzWBbg    244473   enflamed     Divanance     1        900262

# %%
enflamed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362 entries, 0 to 361
# Data columns (total 6 columns):
# log_id          362 non-null object
# spell_id        362 non-null int64
# spell_name      362 non-null object
# player          362 non-null object
# hits            362 non-null int64
# damage_taken    362 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 17.0+ KB

# %%
enflamed.nunique()
# Out:
# log_id           18
# spell_id          1
# spell_name        1
# player           35
# hits             57
# damage_taken    360
# dtype: int64

# %% [markdown]
# Create function for presence count

# %%
def presence_count(log_df, boss_id):
    boss_fights = log_df[log_df['boss_id'] == boss_id]
    df_list = []
    for player in log_df['player_name'].unique():
        count = boss_fights[boss_fights['player_name'] == player].shape[0]
        df_list.append({
            'boss_id': boss_id,
            'player': player,
            'fight_count': count
        })
    
    df = pd.DataFrame(df_list, columns=['boss_id', 'player', 'fight_count'])
    return df

# %%
felhounds_presence = presence_count(df, 2074)
felhounds_presence.head()
# Out:
#    boss_id        player  fight_count
# 0     2074        Petrol           41
# 1     2074  Radiantldeal           40
# 2     2074   Shallowfall           38
# 3     2074       Acturus           41
# 4     2074          Tawñ            0

# %%
def join_fight_count(fight_df, log_df, boss_id):
    fight_count = presence_count(log_df, boss_id)
    df = fight_df.merge(fight_count[['player', 'fight_count']], how='left', on='player')
    return df

# %%
enflamed = join_fight_count(enflamed, df, 2074)
enflamed.head()
# Out:
#              log_id  spell_id spell_name        player  hits  damage_taken  \
# 0  1MJK9vG4qAkzWBbg    244473   enflamed    Thebadlock     8       9313567
# 1  1MJK9vG4qAkzWBbg    244473   enflamed  Brianmurican     8      10496935
# 2  1MJK9vG4qAkzWBbg    244473   enflamed  Radiantldeal    12      14649185
# 3  1MJK9vG4qAkzWBbg    244473   enflamed      Velryssa     7       8912065
# 4  1MJK9vG4qAkzWBbg    244473   enflamed     Divanance     1        900262
#
#    fight_count
# 0           17
# 1           32
# 2           40
# 3           31
# 4           40

# %%
la.change_names(enflamed, player_names)

# %%
enflamed.to_csv('guild_awards/felhounds_enflamed_data.csv', encoding='iso-8859-1', index=False)

# %%
enflamed = pd.read_csv('guild_awards/felhounds_enflamed_data.csv', encoding='iso-8859-1')

# %%
enf_players = enflamed.groupby('player')[['player', 'hits', 'damage_taken']].sum().reset_index()
enf_players.head()
# Out:
#          player  hits  damage_taken
# 0       Acturus   365     454436745
# 1            Au   248     277360944
# 2        Ayriea   306     380213211
# 3         Brian   108     131564043
# 4  Brianmurican   263     332562376

# %%
enf_players = join_fight_count(enf_players, df, 2074)
enf_players.head()
# Out:
#          player  hits  damage_taken  fight_count
# 0       Acturus   365     454436745           41
# 1            Au   248     277360944           26
# 2        Ayriea   306     380213211           39
# 3         Brian   108     131564043            9
# 4  Brianmurican   263     332562376           32

# %%
enf_players.nunique()
# Out:
# player          35
# hits            31
# damage_taken    35
# fight_count     23
# dtype: int64

# %%
la.change_names(enf_players, player_names)
enf_players.nunique()
# Out:
# player          31
# hits            31
# damage_taken    35
# fight_count     23
# dtype: int64

# %%
player_names[['player', 'primary_role']].head()
# Out:
#      player primary_role
# 0   Vaelyra       damage
# 1  Metonymy       damage
# 2     Brian       damage
# 3    Shaami       healer
# 4    Petrol       damage

# %%
def join_player_roles(fight_df, player_names):
    df = fight_df.merge(player_names[['player', 'primary_role']], how='left', on='player')
    return df

# %%
def clean_damge_fight_count(fight_df, log_df, player_names, boss_id):
    # Sum stats by player
    df = fight_df.groupby('player')[['player', 'hits', 'damage_taken']].sum().reset_index()
    # Join hit counts
    df = join_fight_count(df, log_df, boss_id)
    # Manage alts
    la.change_names(df, player_names)
    df = df.groupby('player').sum().reset_index()
    # Join player role
    df = join_player_roles(df, player_names)
    return df

# %%
enf_players = clean_damge_fight_count(enflamed, df, player_names, 2074)
enf_players.head()
# Out:
#     player  hits  damage_taken  fight_count primary_role
# 0  Acturus   365     454436745           41       healer
# 1       Au   248     277360944           26       damage
# 2   Ayriea   306     380213211           39       damage
# 3    Brian   371     464126419           41       damage
# 4   Bryiah    57      68028406            5       damage

# %%
enf_players.nunique()
# Out:
# player          31
# hits            30
# damage_taken    31
# fight_count     20
# dtype: int64

# %%
enf_players['av_hit'] = enf_players.hits / enf_players.fight_count
enf_players.head()
# Out:
#     player  hits  damage_taken  fight_count     av_hit
# 0  Acturus   365     454436745           41   8.902439
# 1       Au   248     277360944           26   9.538462
# 2   Ayriea   306     380213211           39   7.846154
# 3    Brian   371     464126419           41   9.048780
# 4   Bryiah    57      68028406            5  11.400000

# %%
def find_least_hits(df, fight_count):
    new_df = df.copy()
    new_df['av_hit'] = new_df['hits'] / new_df['fight_count']
    new_df = new_df[new_df['fight_count'] >= fight_count]
    new_df.sort_values('av_hit', inplace=True)
    return new_df

# %%
least_av_hit = find_least_hits(enf_players, 30)
least_av_hit
# Out:
#           player  hits  damage_taken  fight_count primary_role     av_hit
# 9          Earrl    54      41748348           41         tank   1.317073
# 8      Divanance    85      76603808           40         tank   2.125000
# 18   Psychodruid   175     208701876           33       damage   5.303030
# 15      Metonymy   260     341066749           41       damage   6.341463
# 26       Vaelyra   239     265888853           36       damage   6.638889
# 5     Cagliostro   251     311661040           37       damage   6.783784
# 21   Shadowbaine   248     329627773           34       damage   7.294118
# 27      Velryssa   243     285234938           31       damage   7.838710
# 2         Ayriea   306     380213211           39       damage   7.846154
# 17        Petrol   323     414587668           41       damage   7.878049
# 22   Shallowfall   302     302793733           38       damage   7.947368
# 10        Future   340     389650253           40       damage   8.500000
# ...

# %%
least_av_hit.to_csv('guild_awards/felhouds_enflamed_hits.csv', encoding='iso-8859-1', index=False)

# %%
felhound_hits = pd.read_csv('guild_awards/felhouds_enflamed_hits.csv', encoding='iso-8859-1')

# %%
sns.distplot(felhound_hits.av_hit, kde=False);
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(least_av_hit, col='primary_role').map(sns.distplot, "av_hit");
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# <a id='highc'></a>
# ## High Command

# %% [markdown]
# Boss ID: 2070

# %% [markdown]
# <a id='highc-dispell'></a>
# ### Dispells

# %% [markdown]
# **Spell IDs**
# - Priest: Purify (527), Mass Dispel (32375)
# - Paladin: Cleanse (4987)
# - Shaman: Purify Spirit (77130)

# %% [markdown]
# Spell ID: 527

# %%
spell_id_527 = wl.cast_count(api_key, df, 527, 'purify', 2070)
# Out:
# ...
# Player added: Radiantldeal
# Player added: Mythrose
# ...
# Player added: Mythrose
# ...
# Player added: Radiantldeal
# Player added: Mythrose
# ...
# Player added: Mythrose
# ...
# Player added: Radiantldeal
# ...
# Player added: Mythrose
# ...
# Player added: Mythrose

# %%
spell_id_527
# Out:
#              log_id  spell_id spell_name        player  count
# 0  6f7xWYP9JLdz4XjB       527     purify  Radiantldeal     24
# 1  6f7xWYP9JLdz4XjB       527     purify      Mythrose     33
# 2  96FwjyP38bYTkmDf       527     purify      Mythrose     20
# 3  gbTRy3GhdN9CY46r       527     purify  Radiantldeal      2
# 4  gbTRy3GhdN9CY46r       527     purify      Mythrose     93
# 5  JXLwKGarqfT2mvMP       527     purify      Mythrose     15
# 6  P6jqnm2cH7vxJdkY       527     purify  Radiantldeal      1
# 7  Wc18VDX9wQ62hTjy       527     purify      Mythrose    115
# 8  YGa62MVkATCdL4Zp       527     purify      Mythrose      1

# %% [markdown]
# Spell ID: 32375

# %%
spell_id_32375 = wl.cast_count(api_key, df, 32375, 'mass dispel', 2070)
# Out:
# ...
# Player added: Radiantldeal
# ...

# %%
spell_id_32375
# Out:
#              log_id  spell_id   spell_name        player  count
# 0  6f7xWYP9JLdz4XjB     32375  mass dispel  Radiantldeal      2

# %% [markdown]
# Spell ID: 4987

# %%
spell_id_4987 = wl.cast_count(api_key, df, 4987, 'cleanse', 2070)
# Out:
# ...
# Player added: Acturus
# ...
# Player added: Acturus
# ...
# Player added: Acturus
# ...
# Player added: Acturus
# ...
# Player added: Acturus
# ...
# Player added: Acturus
# ...
# Player added: Acturus
# ...
# Player added: Acturus
# ...
# Player added: Acturus
# ...
# Player added: Acturus
# ...
# Player added: Acturus
# ...
# Player added: Acturus
# ...
# Player added: Acturus
# ...
# Player added: Acturus
# ...
# Player added: Acturus
# ...
# Player added: Acturus

# %%
spell_id_4987
# Out:
#               log_id  spell_id spell_name   player  count
# 0   2c6whdrGDkKHP7Nv      4987    cleanse  Acturus     19
# 1   4AP62tL1NzjfFWd7      4987    cleanse  Acturus     19
# 2   6f7xWYP9JLdz4XjB      4987    cleanse  Acturus      9
# 3   7H6FtpVr9c4xaW8L      4987    cleanse  Acturus     13
# 4   82BfPKG7bpAjqLzh      4987    cleanse  Acturus     49
# 5   96FwjyP38bYTkmDf      4987    cleanse  Acturus      3
# 6   AhPtzwGQm9Mg8rTa      4987    cleanse  Acturus     46
# 7   bvV2YFyrRQdpJ6xf      4987    cleanse  Acturus     24
# 8   dZfYj6ynTA21WDxa      4987    cleanse  Acturus     18
# 9   gbTRy3GhdN9CY46r      4987    cleanse  Acturus    115
# 10  hDTjXr8H3FqtNLk1      4987    cleanse  Acturus     15
# 11  JXLwKGarqfT2mvMP      4987    cleanse  Acturus     65
# 12  P6jqnm2cH7vxJdkY      4987    cleanse  Acturus     35
# 13  TJPXdVcafZ49tLGm      4987    cleanse  Acturus     17
# 14  Wc18VDX9wQ62hTjy      4987    cleanse  Acturus     89
# ...

# %%
spell_id_77130 = wl.cast_count(api_key, df, 77130, 'purify spirit', 2070)
# Out:
# ...
# Player added: Illestra
# Player added: Zephyyra
# ...
# Player added: Illestra
# ...
# Player added: Illestra
# ...
# Player added: Zephyyra
# Player added: Illestra
# ...
# Player added: Illestra
# ...
# Player added: Illestra
# ...
# Player added: Illestra
# ...
# Player added: Illestra
# Player added: Zephyyra
# ...
# Player added: Illestra
# Player added: Zephyyra
# ...
# Player added: Illestra
# ...
# Player added: Zephyyra
# Player added: Illestra
# ...
# Player added: Illestra
# ...
# Player added: Illestra
# ...
# Player added: Illestra
# ...
# Player added: Illestra
# ...
# Player added: Illestra

# %%
spell_id_77130
# Out:
#               log_id  spell_id     spell_name    player  count
# 0   2c6whdrGDkKHP7Nv     77130  purify spirit  Illestra     18
# 1   2c6whdrGDkKHP7Nv     77130  purify spirit  Zephyyra      5
# 2   4AP62tL1NzjfFWd7     77130  purify spirit  Illestra     14
# 3   6f7xWYP9JLdz4XjB     77130  purify spirit  Illestra     30
# 4   7H6FtpVr9c4xaW8L     77130  purify spirit  Zephyyra     10
# 5   7H6FtpVr9c4xaW8L     77130  purify spirit  Illestra     14
# 6   82BfPKG7bpAjqLzh     77130  purify spirit  Illestra     32
# 7   96FwjyP38bYTkmDf     77130  purify spirit  Illestra     16
# 8   AhPtzwGQm9Mg8rTa     77130  purify spirit  Illestra     25
# 9   bvV2YFyrRQdpJ6xf     77130  purify spirit  Illestra     11
# 10  bvV2YFyrRQdpJ6xf     77130  purify spirit  Zephyyra     15
# 11  dZfYj6ynTA21WDxa     77130  purify spirit  Illestra     19
# 12  dZfYj6ynTA21WDxa     77130  purify spirit  Zephyyra     15
# 13  gbTRy3GhdN9CY46r     77130  purify spirit  Illestra     70
# ...

# %% [markdown]
# Create full df

# %%
highc_dispels = pd.concat([spell_id_527, spell_id_32375, spell_id_4987, spell_id_77130])
highc_dispels.head()
# Out:
#              log_id  spell_id spell_name        player  count
# 0  6f7xWYP9JLdz4XjB       527     purify  Radiantldeal     24
# 1  6f7xWYP9JLdz4XjB       527     purify      Mythrose     33
# 2  96FwjyP38bYTkmDf       527     purify      Mythrose     20
# 3  gbTRy3GhdN9CY46r       527     purify  Radiantldeal      2
# 4  gbTRy3GhdN9CY46r       527     purify      Mythrose     93

# %%
highc_dispels.to_csv('guild_awards/highc_dispels_data.csv', encoding='iso-8859-1', index=False)

# %% [markdown]
# Read in df

# %%
highc_dispels = pd.read_csv('guild_awards/highc_dispels_data.csv', encoding='iso-8859-1')

# %%
def clean_cast_fight_count(fight_df, log_df, player_names, boss_id):
    '''
    Adds fight counts, substitute alt names and combines with substituted names.

    args:
        fight_df: pandas DataFrame of fight statistics.
        log_df: pandas DataFrame from master_list.csv.
        player_names: pandas DataFrame from player_list.csv.
        boss_id: (int) Code for boss encounter as defined in World of Warcraft.
    returns:
        pandas DataFrame.
    '''
    # Sum stats by player
    df = fight_df.groupby('player')['count'].sum().reset_index()
    # Join fight counts
    df = la.join_fight_count(df, log_df, boss_id)
    # Manage alts
    la.change_names(df, player_names)
    df = df.groupby('player').sum().reset_index()
    # Join player role
    df = la.join_player_roles(df, player_names)

    return df

# %%
hc_dispel_counts = clean_cast_fight_count(highc_dispels, df, player_names, 2070)
hc_dispel_counts.head()
# Out:
#          player  count  fight_count primary_role
# 0       Acturus    586           87       healer
# 1      Illestra    548           87       healer
# 2      Mythrose    277           87       healer
# 3  Radiantldeal     29           87       healer
# 4      Zephyyra     54            7       healer

# %%
hc_dispel_counts.to_csv('guild_awards/highc_dispel_count.csv', encoding='iso-8859-1', index=False)

# %%
sns.barplot(x='player', y='count', data=hc_dispel_counts);

# %% [markdown]
# <a id='highc-bombs'></a>
# ### Least bomb hits

# %%
df.query('log_id == "gbTRy3GhdN9CY46r" & boss_name == "Antoran High Command"').pull_end.max()
# Out:
# 10847957

# %% [markdown]
# Spell ID: 245121

# %%
bombs = wl.damage_taken(api_key, df, 245121, 'entropic bomb', 2070, 10)
# Out:
# ...
# Player added: Tinytiki
# Player added: Cagliostro
# Player added: Shallowfall
# Player added: Mythrose
# Player added: Znoch
# Player added: Acturus
# Player added: Radiantldeal
# Player added: Velryssa
# Player added: Shadowbaine
# Player added: Kyarrix
# Player added: Zephyyra
# Player added: Au
# Player added: Illestra
# Player added: Metonymy
# Player added: Divanance
# Player added: Brian
# Player added: Earrl
# Player added: Vaelyra
# ...
# Player added: Illestra
# Player added: Au
# Player added: Metonymy
# Player added: Earrl
# Player added: Velryssa
# Player added: Acturus
# Player added: Radiantldeal
# Player added: Thebadlock
# Player added: Kamer
# Player added: Psychodruid
# Player added: Brianmurican
# Player added: Divanance
# Player added: Tinytiki
# Player added: Znoch
# Player added: Shadowbaine
# Player added: Ayriea
# Player added: Shallowfall
# Player added: Cagliostro
# ...
# Player added: Radiantldeal
# Player added: Googboog
# Player added: Cinzia
# ...

# %%
bombs.head()
# Out:
#              log_id  spell_id     spell_name       player  hits  damage_taken
# 0  2c6whdrGDkKHP7Nv    245121  entropic bomb     Tinytiki     3       8260311
# 1  2c6whdrGDkKHP7Nv    245121  entropic bomb   Cagliostro     2       5499449
# 2  2c6whdrGDkKHP7Nv    245121  entropic bomb  Shallowfall     3       5674590
# 3  2c6whdrGDkKHP7Nv    245121  entropic bomb     Mythrose     1       2838152
# 4  2c6whdrGDkKHP7Nv    245121  entropic bomb        Znoch     5      12822769

# %%
bombs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 6 columns):
# log_id          300 non-null object
# spell_id        300 non-null int64
# spell_name      300 non-null object
# player          300 non-null object
# hits            300 non-null int64
# damage_taken    300 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 14.1+ KB

# %%
bombs.nunique()
# Out:
# log_id           16
# spell_id          1
# spell_name        1
# player           33
# hits             46
# damage_taken    300
# dtype: int64

# %%
bombs.to_csv('guild_awards/highc_bomb_data.csv', encoding='iso-8859-1', index=False)

# %% [markdown]
# Read in info

# %%
bombs = pd.read_csv('guild_awards/highc_bomb_data.csv', encoding='iso-8859-1')

# %%
bomb_count = la.clean_fight_count(bombs, df, player_names, 2070, ['hits', 'damage_taken'])
bomb_count.head()
# Out:
#     player  hits  damage_taken  fight_count primary_role
# 0  Acturus   124     308914428           87       healer
# 1       Au    88     201555546           40       damage
# 2   Ayriea    80     203070873           85       damage
# 3    Brian    80     197814950           87       damage
# 4   Bryiah   120     260388079           52       damage

# %%
bomb_count.nunique()
# Out:
# player          29
# hits            24
# damage_taken    29
# fight_count     19
# primary_role     3
# dtype: int64

# %%
least_bomb_hits = la.find_count_order(bomb_count, 60, 'hits')
least_bomb_hits
# Out:
#           player  hits  damage_taken  fight_count primary_role   av_count
# 6         Cinzia    27      71820759           70       damage   0.385714
# 16        Petrol    46     128222381           87       damage   0.528736
# 14      Metonymy    61     165842686           87       damage   0.701149
# 3          Brian    80     197814950           87       damage   0.919540
# 2         Ayriea    80     203070873           85       damage   0.941176
# 15      Mythrose    84     217575723           87       healer   0.965517
# 19  Radiantldeal    88     200233727           87       healer   1.011494
# 11      Illestra   121     275671478           87       healer   1.390805
# 9         Future   121     306001378           86       damage   1.406977
# 0        Acturus   124     308914428           87       healer   1.425287
# 17   Psychodruid   112     272624343           75       damage   1.493333
# 21   Shallowfall   113     238052276           68       damage   1.661765
# ...

# %%
least_bomb_hits.to_csv('guild_awards/highc_bomb_hits.csv', encoding='iso-8859-1', index=False)

# %%
sns.distplot(least_bomb_hits.query('av_count <5').av_count)
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(least_bomb_hits, col='primary_role').map(sns.distplot, "av_count");
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# <a id='portalk'></a>
# ## Portal Keeper

# %% [markdown]
# Boss ID: 2064

# %% [markdown]
# <a id='portalk-interupts'></a>
# ### Interupts

# %% [markdown]
# **Spell IDs**
# - Mage: Counterspell (2139), Dragon's Breath (31661)
# - Druid: Solar Beam (78675), Typhoon (61391)
# - Warrior: Pummel (6552), Intimidating Shout (5246)
# - Hunter: Counter Shot (147362)
# - DK: Mind Freeze (47528)
# - Rogue: Kick (1766), Kidney Shot (408)
# - DH: Consume Magic (183752)
# - Shaman: Wind Shear (57994), Lightning/Cap Totem (192058), Earthquake (61882)
# - Paladin: Rebuke (96231)

# %%
spell_ids = [31661, 78675, 61391, 6552, 5246, 147362, 47528, 1766, 408, 183752, 57994, 192058, 61882, 96231]

# %%
interrupt_df = wl.cast_count(api_key, df, 2139, boss_id=2064)
# Out:
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Petrol
# Player added: Metonymy
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Petrol
# ...
# Player added: Petrol
# Player added: Metonymy
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Petrol
# Player added: Metonymy

# %%
for spell in spell_ids:
    spell_df = wl.cast_count(api_key, df, spell, boss_id=2064)
    interrupt_df = pd.concat([interrupt_df, spell_df])
# Out:
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Petrol
# Player added: Metonymy
# ...
# Player added: Petrol
# Player added: Metonymy
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Petrol
# Player added: Metonymy
# ...
# Player added: Petrol
# Player added: Metonymy
# ...
# Player added: Petrol
# ...
# Player added: Petrol
# Player added: Metonymy
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Petrol
# Player added: Metonymy
# ...
# Player added: Psychodruid
# ...
# Player added: Psychodruid
# ...
# Player added: Psychodruid
# ...
# Player added: Psychodruid
# ...
# Player added: Psychodruid
# ...
# Player added: Psychodruid
# ...
# Player added: Psychodruid
# ...
# Player added: Psychodruid
# ...
# Player added: Earrl
# ...
# Player added: Earrl
# ...
# Player added: Earrl
# ...
# Player added: Psychodruid
# Player added: Earrl
# ...
# Player added: Psychodruid
# ...
# Player added: Psychodruid
# ...
# Player added: Psychodruid
# ...

# %%
interrupt_df.head()
# Out:
#              log_id  spell_id    player  count
# 0  2c6whdrGDkKHP7Nv      2139  Metonymy     11
# 1  2c6whdrGDkKHP7Nv      2139    Petrol      9
# 2  7H6FtpVr9c4xaW8L      2139    Petrol      3
# 3  7H6FtpVr9c4xaW8L      2139  Metonymy      6
# 4  AhPtzwGQm9Mg8rTa      2139  Metonymy     31

# %%
interrupt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 229 entries, 0 to 14
# Data columns (total 4 columns):
# log_id      229 non-null object
# spell_id    229 non-null int64
# player      229 non-null object
# count       229 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 8.9+ KB

# %%
interrupt_df.to_csv('guild_awards/portal_keeper_interupts_data.csv', encoding='iso-8859-1', index=False)

# %% [markdown]
# Read in df

# %%
interupt_df = pd.read_csv('guild_awards/portal_keeper_interupts_data.csv', encoding='iso-8859-1')

# %%
interupt_count = la.clean_fight_count(interupt_df, df, player_names, 2064, column_names=['count'])

# %%
interupt_count.head()
# Out:
#        player  count  fight_count primary_role
# 0          Au     24           62       damage
# 1      Ayriea    159           57       damage
# 2       Brian    150           62       damage
# 3      Bryiah     42           16       damage
# 4  Cagliostro    140           52       damage

# %%
most_interupts = la.find_count_order(interupt_count, 10, 'count', least=False)
most_interupts
# Out:
#          player  count  fight_count primary_role   av_count
# 8        Future   1148           61       damage  18.819672
# 13     Metonymy    387           61       damage   6.344262
# 14       Petrol    320           62       damage   5.161290
# 18     Tinytiki    121           31       damage   3.903226
# 16  Shallowfall    241           62       damage   3.887097
# 9      Googboog    121           42       damage   2.880952
# 15  Psychodruid    109           38       damage   2.868421
# 1        Ayriea    159           57       damage   2.789474
# 4    Cagliostro    140           52       damage   2.692308
# 3        Bryiah     42           16       damage   2.625000
# 2         Brian    150           62       damage   2.419355
# 5        Cinzia     23           14       damage   1.642857
# 19      Vaelyra     95           62       damage   1.532258
# 20     Velryssa     56           39       damage   1.435897
# 6     Divanance     54           62         tank   0.870968
# ...

# %%
most_interupts.to_csv('guild_awards/portal_keeper_interupts_count.csv', encoding='iso-8859-1', index=False)

# %% [markdown]
# <a id='portalk-adds'></a>
# ### Add Damage

# %% [markdown]
# **Add IDs**
# - Blazing Imp (122783)
# - Feltouched Skitterer (123702)
# - Hungering Stalker (123223)

# %% [markdown]
# #### Query Tests

# %%
df.query('log_id == "TJPXdVcafZ49tLGm"').pull_end.max()
# Out:
# 10928125

# %%
damage_done = requests.get('https://www.warcraftlogs.com:443/v1/report/tables/damage-taken/TJPXdVcafZ49tLGm?end=10928125&hostility=1&by=target&encounter=2064&difficulty=5&api_key=' + api_key)
details = damage_done.json()
details
# Out:
# {'entries': [{'name': 'Greater Fire Elemental',
#    'id': 78,
#    'guid': 95061,
#    'type': 'Pet',
#    'icon': 'abilities/spell_fire_elemental_totem',
#    'total': 43890864,
#    'activeTime': 231555,
#    'overheal': -43890864,
#    'abilities': [{'name': 'Fire Blast', 'total': 43890864, 'type': 4}],
#    'damageAbilities': [],
#    'targets': [{'name': 'Portal Keeper Hasabel',
#      'total': 43001235,
#      'type': 'Boss'},
#     {'name': 'Hungering Stalker', 'total': 593086, 'type': 'NPC'},
#     {'name': 'Blazing Imp', 'total': 296543, 'type': 'NPC'}]},
#   {'name': 'Petrol',
#    'id': 24,
#    'guid': 110737162,
#    'type': 'Mage',
#    'itemLevel': 972,
#    'icon': 'Mage-Fire',
#    'total': 1972240646,
#    'activeTime': 974331,
#    'activeTimeReduced': 974331,
#    'overheal': -1972240646,
#    'abilities': [{'name': 'Ignite', 'total': 570452110, 'type': 4},
#     {'name': 'Pyroblast', 'total': 488995915, 'type': 4},
# ...

# %%
details.keys()
# Out:
# dict_keys(['entries', 'totalTime', 'logVersion'])

# %%
details['entries'][1]
# Out:
# {'name': 'Petrol',
#  'id': 24,
#  'guid': 110737162,
#  'type': 'Mage',
#  'itemLevel': 972,
#  'icon': 'Mage-Fire',
#  'total': 1972240646,
#  'activeTime': 974331,
#  'activeTimeReduced': 974331,
#  'overheal': -1972240646,
#  'abilities': [{'name': 'Ignite', 'total': 570452110, 'type': 4},
#   {'name': 'Pyroblast', 'total': 488995915, 'type': 4},
#   {'name': 'Legion Bombardment', 'total': 179310434, 'type': 4},
#   {'name': "Dragon's Breath", 'total': 165735377, 'type': 4},
#   {'name': 'Fireball', 'total': 141773155, 'type': 4}],
#  'damageAbilities': [],
#  'targets': [{'name': 'Portal Keeper Hasabel',
#    'total': 1482964681,
#    'type': 'Boss'},
#   {'name': 'Blazing Imp', 'total': 358402393, 'type': 'NPC'},
#   {'name': 'Feltouched Skitterer', 'total': 101445087, 'type': 'NPC'},
#   {'name': 'Hungering Stalker', 'total': 29428485, 'type': 'NPC'}],
#  'talents': [{'name': 'Firestarter',
#    'guid': 205026,
#    'type': 1,
#    'abilityIcon': 'spell_fire_fire.jpg'},
# ...

# %%
details['entries'][1]['name']
# Out:
# 'Petrol'

# %%
details['entries'][0]['type']
# Out:
# 'Pet'

# %%
details['entries'][1]['targets']
# Out:
# [{'name': 'Portal Keeper Hasabel', 'total': 1482964681, 'type': 'Boss'},
#  {'name': 'Blazing Imp', 'total': 358402393, 'type': 'NPC'},
#  {'name': 'Feltouched Skitterer', 'total': 101445087, 'type': 'NPC'},
#  {'name': 'Hungering Stalker', 'total': 29428485, 'type': 'NPC'}]

# %%
details['entries'][1]['targets'][1]['name']
# Out:
# 'Blazing Imp'

# %%
details['entries'][1]['targets'][1]['type']
# Out:
# 'NPC'

# %% [markdown]
# #### Create function

# %%
def create_link_damage_done(api_key, log_df, log, boss_id=None):
    # Create link components
    end = log_df[log_df['log_id'] == log].pull_end.max()
    link_start = 'https://www.warcraftlogs.com:443/v1/report/tables/damage-taken/'
    end_info = '?end=' + str(end) + '&'
    target_info = 'hostility=1&by=target&'
    boss_info = 'encounter=' + str(boss_id) + '&'
    if boss_id is None:
        boss_info = ''
    link_end = 'difficulty=5&api_key=' + api_key
    
    # Create link
    link = link_start + log + end_info + target_info + boss_info + link_end
    
    return link

# %%
def damage_done(api_key, log_df, boss_id=None, NPC=True):
    df_list = []
    logs = wl.get_log_ids(log_df, boss_id)
    for log in logs:
        print('Collecting details for log', log)
        
        # Complete query
        link = create_link_damage_done(api_key, log_df, log, boss_id)
        details = wl.get_query_details(link)
        
        # Get player info
        for player in details['entries']:
            if player['type'] == 'Pet':
                continue
            name = player['name']
            print('Player added:', name)
            damage = 0
            # Collect damage for NPC or boss
            for target in player['targets']:
                if NPC is True:
                    if target['type'] == 'NPC':
                        damage += target['total']
                else:
                    if target['type'] == 'Boss':
                        damage += target['total']
            df_list.append({
                'log_id': log,
                'player': name,
                'NPC': NPC,
                'damage_done': damage
            })
        
    # Create dataframe
    df = pd.DataFrame(df_list, columns=['log_id', 'player', 'NPC', 'damage_done'])
    
    return df

# %% [markdown]
# #### Gather info

# %%
add_damage = damage_done(api_key, df, 2064)
# Out:
# ...
# Player added: Earrl
# Player added: Metonymy
# Player added: Cagliostro
# Player added: Shallowfall
# Player added: Petrol
# Player added: Bryiah
# Player added: Kyarrix
# Player added: Shadowbaine
# Player added: Illestra
# Player added: Divanance
# Player added: Mythrose
# Player added: Au
# Player added: Znoch
# Player added: Vaelyra
# Player added: Acturus
# Player added: Ayriea
# Player added: Brian
# Player added: Tinytiki
# ...
# Player added: Illestra
# Player added: Shadowbaine
# Player added: Kamer
# Player added: Brianmurican
# Player added: Metonymy
# Player added: Acturus
# Player added: Mythrose
# Player added: Velryssa
# Player added: Au
# Player added: Petrol
# Player added: Psychodruid
# Player added: Divanance
# Player added: Thebadlock
# Player added: Shallowfall
# Player added: Earrl
# Player added: Ayriea
# Player added: Vaelyra
# Player added: Tinytiki
# Player added: Znoch
# ...
# Player added: Stradivarus
# Player added: Vaelyra
# Player added: Au
# ...

# %%
add_damage.head()
# Out:
#              log_id       player   NPC  damage_done
# 0  2c6whdrGDkKHP7Nv        Earrl  True    185792284
# 1  2c6whdrGDkKHP7Nv     Metonymy  True    579020116
# 2  2c6whdrGDkKHP7Nv   Cagliostro  True    358152192
# 3  2c6whdrGDkKHP7Nv  Shallowfall  True    203024457
# 4  2c6whdrGDkKHP7Nv       Petrol  True    736996038

# %%
add_damage.to_csv('guild_awards/portal_keeper_adds_data.csv', encoding='iso-8859-1', index=False)

# %% [markdown]
# Read in info

# %%
add_damage = pd.read_csv('guild_awards/portal_keeper_adds_data.csv', encoding='iso-8859-1')

# %%
total_damage = la.clean_fight_count(add_damage, df, player_names, 2064, column_names=['damage_done'])
total_damage.head()
# Out:
#     player  damage_done  fight_count primary_role
# 0  Acturus    165919634           62       healer
# 1       Au   4659106627           62       damage
# 2   Ayriea   2415400302           57       damage
# 3    Brian   5773356929           62       damage
# 4   Bryiah   2248201684           16       damage

# %%
total_damage = la.find_count_order(total_damage, 30, 'damage_done', least=False)
total_damage
# Out:
#           player  damage_done  fight_count primary_role      av_count
# 24       Vaelyra   8130174136           62       damage  1.311318e+08
# 25      Velryssa   5091633176           39       damage  1.305547e+08
# 9         Future   7790329412           61       damage  1.277103e+08
# 16        Petrol   7797206525           62       damage  1.257614e+08
# 17   Psychodruid   4442523437           38       damage  1.169085e+08
# 14      Metonymy   7110291810           61       damage  1.165622e+08
# 23      Tinytiki   3121877855           31       damage  1.007057e+08
# 3          Brian   5773356929           62       damage  9.311866e+07
# 20   Shadowbaine   5293680619           62       damage  8.538195e+07
# 10      Googboog   3582604243           42       damage  8.530010e+07
# 5     Cagliostro   4089895649           52       damage  7.865184e+07
# 1             Au   4659106627           62       damage  7.514688e+07
# ...

# %%
total_damage.to_csv('guild_awards/portal_keeper_add_damage.csv', encoding='iso-8859-1', index=False)

# %% [markdown]
# <a id='eonar'></a>
# ## Eonar

# %% [markdown]
# Spell IDs: 249016 & 249015

# %% [markdown]
# #### Query Tests

# %% [markdown]
# Find pull end time for log with Eonar fights

# %%
df.query('log_id == "vYDj1qQgcXWdmTnF"').pull_end.max()
# Out:
# 10305202

# %% [markdown]
# Run query for debuff on targets for log

# %%
debuff = requests.get('https://www.warcraftlogs.com:443/v1/report/tables/debuffs/vYDj1qQgcXWdmTnF?end=10305202&by=source&abilityid=249016&api_key=' + api_key)
details = debuff.json()
details
# Out:
# {'auras': [{'name': 'Èllipses',
#    'id': 3,
#    'guid': 137327868,
#    'type': 'Warlock',
#    'icon': 'Warlock-Affliction',
#    'totalUptime': 392648,
#    'totalUses': 2,
#    'bands': [{'startTime': 1587803, 'endTime': 1779949},
#     {'startTime': 2285588, 'endTime': 2486090}]},
#   {'name': 'Ayriea',
#    'id': 17,
#    'guid': 132573980,
#    'type': 'Hunter',
#    'icon': 'Hunter-BeastMastery',
#    'totalUptime': 606958,
#    'totalUses': 3,
#    'bands': [{'startTime': 1472757, 'endTime': 1779949},
#     {'startTime': 2186324, 'endTime': 2486090}]},
#   {'name': 'Petrol',
#    'id': 7,
#    'guid': 110737162,
#    'type': 'Mage',
#    'icon': 'Mage-Fire',
#    'totalUptime': 885889,
#    'totalUses': 2,
#    'bands': [{'startTime': 1331271, 'endTime': 1779949},
#     {'startTime': 2048879, 'endTime': 2486090}]},
#   {'name': 'Undertakerop',
#    'id': 25,
#    'guid': 157445886,
#    'type': 'DeathKnight',
#    'icon': 'DeathKnight-Frost',
#    'totalUptime': 175560,
# ...

# %%
details.keys()
# Out:
# dict_keys(['auras', 'useTargets', 'totalTime', 'startTime', 'endTime'])

# %% [markdown]
# Get name and counts

# %%
details['auras'][0]['name']
# Out:
# 'Èllipses'

# %%
details['auras'][0]['totalUses']
# Out:
# 2

# %% [markdown]
# #### Create function

# %%
for log in df['log_id'].unique():
    print(log)
    break
# Out:
# 1dApmwBHyQ2vcVTF

# %%
df[df['log_id'] == '1dApmwBHyQ2vcVTF'].pull_end.max()
# Out:
# 10679403

# %%
def buff_count(api_key, log_df, spell_id, spell_name=None, description=None, boss_id=None, buff=True):
    df_list = []
    logs = get_logs(log_df, boss_id)
    for log in logs:
        print('Collecting details for log', log)
        
        # Create link
        end = log_df[log_df['log_id'] == log].pull_end.max()
        if buff is True:
            link = 'https://www.warcraftlogs.com:443/v1/report/tables/buffs/' + log + '?end=' + str(end) + \
            '&by=source&abilityid=' + str(spell_id) + '&api_key='
        else:
            link = 'https://www.warcraftlogs.com:443/v1/report/tables/debuffs/' + log + '?end=' + str(end) + \
            '&by=source&abilityid=' + str(spell_id) + '&api_key='
        
        # Complete query
        event = requests.get(link + api_key)
        details = event.json()
        
        # Get player info
        for player in details['auras']:
            name = player['name']
            print('Player added:', name)
            duration = player['totalUptime']
            df_list.append({
                'log_id': log, 
                'spell_id': spell_id,
                'spell_name': spell_name,
                'description': description,
                'player': name,
                'duration': duration
            })
    
    # Create dataframe
    df = pd.DataFrame(df_list, columns=['log_id', 'spell_id', 'spell_name', 'description', 'player', 'duration'])
    # Manage excluded spell info
    if spell_name is None:
        df.drop('spell_name', axis=1, inplace=True)
    if description is None:
        df.drop('description', axis=1, inplace=True)
    
    return df

# %%
test = df.query('log_id == "vYDj1qQgcXWdmTnF"')

# %%
extra_damage = buff_count(api_key, test, 249016, 'Feedback - Targeted', 'extra damage taken', buff=False)
# Out:
# ...
# Player added: Ayriea
# Player added: Petrol
# Player added: Èllipses
# Player added: Undertakerop

# %%
extra_damage.head()
# Out:
#              log_id  debuff_id          debuff_name  debuff_description  \
# 0  vYDj1qQgcXWdmTnF     249016  Feedback - Targeted  extra damage taken
# 1  vYDj1qQgcXWdmTnF     249016  Feedback - Targeted  extra damage taken
# 2  vYDj1qQgcXWdmTnF     249016  Feedback - Targeted  extra damage taken
# 3  vYDj1qQgcXWdmTnF     249016  Feedback - Targeted  extra damage taken
#
#          player  debuff_duration
# 0        Ayriea           606958
# 1        Petrol           885889
# 2      Èllipses           392648
# 3  Undertakerop           175560

# %% [markdown]
# #### Get debuff durations

# %%
df.boss_name.unique()
# Out:
# array(['Argus the Unmaker', 'Felhounds of Sargeras', 'Varimathras',
#        'The Coven of Shivarra', 'Aggramar', 'Garothi Worldbreaker',
#        'Antoran High Command', 'Portal Keeper Hasabel',
#        'The Defense of Eonar', "Kin'garoth", 'Imonar the Soulhunter'],
#       dtype=object)

# %%
df.query('boss_name == "The Defense of Eonar"').boss_id.max()
# Out:
# 2075

# %%
extra_damage = wl.buff_duration(api_key, df, 249016, 'Feedback - Targeted', 'extra damage taken', 2075, buff=False)
# Out:
# ...
# Player added: Ayriea
# Player added: Shadowbaine
# Player added: Brian
# Player added: Tinytiki
# Player added: Petrol
# ...
# Player added: Stradivarus
# Player added: Bryiah
# Player added: Petrol
# Player added: Verle
# ...
# Player added: Bryiah
# Player added: Pulsè
# Player added: Petrol
# Player added: Illestra
# Player added: Ayriea
# ...
# Player added: Radiantldeal
# Player added: Ayriea
# Player added: Thebadlock
# Player added: Petrol
# Player added: Bryiah
# ...
# Player added: Shadowbaine
# Player added: Brian
# Player added: Èllipses
# Player added: Ayriea
# ...
# Player added: Psychodruid
# Player added: Thebadlock
# Player added: Au
# Player added: Kamer
# ...
# Player added: Future
# Player added: Pulsè
# Player added: Ayriea
# Player added: Shadowbaine
# ...
# Player added: Shadowbaine
# Player added: Brian
# Player added: Kamer
# Player added: Acturus
# ...
# Player added: Petrol
# Player added: Tinytiki
# Player added: Shallowfall
# Player added: Ayriea
# ...
# Player added: Petrol
# ...
# Player added: Yoked
# ...

# %%
extra_damage.head()
# Out:
#              log_id  spell_id           spell_name         description  \
# 0  2c6whdrGDkKHP7Nv    249016  Feedback - Targeted  extra damage taken
# 1  2c6whdrGDkKHP7Nv    249016  Feedback - Targeted  extra damage taken
# 2  2c6whdrGDkKHP7Nv    249016  Feedback - Targeted  extra damage taken
# 3  2c6whdrGDkKHP7Nv    249016  Feedback - Targeted  extra damage taken
# 4  2c6whdrGDkKHP7Nv    249016  Feedback - Targeted  extra damage taken
#
#         player  duration
# 0       Ayriea    536246
# 1  Shadowbaine    439981
# 2        Brian     89248
# 3     Tinytiki    329352
# 4       Petrol    343314

# %%
extra_damage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 6 columns):
# log_id         64 non-null object
# spell_id       64 non-null int64
# spell_name     64 non-null object
# description    64 non-null object
# player         64 non-null object
# duration       64 non-null int64
# dtypes: int64(2), object(4)
# memory usage: 3.1+ KB

# %%
knock_back = wl.buff_duration(api_key, df, 249015, 'Feedback - Burning Embers', 'knock into air', 2075, buff=False)
# Out:
# ...
# Player added: Shadowbaine
# Player added: Petrol
# Player added: Kyarrix
# Player added: Znoch
# Player added: Metonymy
# ...
# Player added: Metonymy
# Player added: Shadowbaine
# Player added: Psychodruid
# Player added: Brian
# ...
# Player added: Shadowbaine
# Player added: Metonymy
# Player added: Kyarrix
# Player added: Brian
# ...
# Player added: Psychodruid
# Player added: Brian
# Player added: Metonymy
# Player added: Shadowbaine
# ...
# Player added: Petrol
# Player added: Kyarrix
# Player added: Metonymy
# Player added: Znoch
# ...
# Player added: Brianmurican
# Player added: Petrol
# Player added: Znoch
# Player added: Metonymy
# ...
# Player added: Kyarrix
# Player added: Psychodruid
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Kyarrix
# Player added: Metonymy
# Player added: Petrol
# Player added: Psychodruid
# ...
# Player added: Znoch
# Player added: Metonymy
# Player added: Psychodruid
# Player added: Brianmurican
# ...
# Player added: Znoch
# ...
# Player added: Kyarrix
# Player added: Brian
# ...

# %%
knock_back.head()
# Out:
#              log_id  spell_id                 spell_name     description  \
# 0  2c6whdrGDkKHP7Nv    249015  Feedback - Burning Embers  knock into air
# 1  2c6whdrGDkKHP7Nv    249015  Feedback - Burning Embers  knock into air
# 2  2c6whdrGDkKHP7Nv    249015  Feedback - Burning Embers  knock into air
# 3  2c6whdrGDkKHP7Nv    249015  Feedback - Burning Embers  knock into air
# 4  2c6whdrGDkKHP7Nv    249015  Feedback - Burning Embers  knock into air
#
#         player  duration
# 0  Shadowbaine    339102
# 1       Petrol    445989
# 2      Kyarrix    326939
# 3        Znoch     92884
# 4     Metonymy    535104

# %%
debuffs_df = pd.concat([extra_damage, knock_back])
debuffs_df.head()
# Out:
#              log_id  spell_id           spell_name         description  \
# 0  2c6whdrGDkKHP7Nv    249016  Feedback - Targeted  extra damage taken
# 1  2c6whdrGDkKHP7Nv    249016  Feedback - Targeted  extra damage taken
# 2  2c6whdrGDkKHP7Nv    249016  Feedback - Targeted  extra damage taken
# 3  2c6whdrGDkKHP7Nv    249016  Feedback - Targeted  extra damage taken
# 4  2c6whdrGDkKHP7Nv    249016  Feedback - Targeted  extra damage taken
#
#         player  duration
# 0       Ayriea    536246
# 1  Shadowbaine    439981
# 2        Brian     89248
# 3     Tinytiki    329352
# 4       Petrol    343314

# %%
debuffs_df.to_csv('guild_awards/eonar_debuff_data.csv', encoding='iso-8859-1', index=False)

# %% [markdown]
# Read in debuff info

# %%
debuffs_df = pd.read_csv('guild_awards/eonar_debuff_data.csv', encoding='iso-8859-1')

# %%
debuff_count = la.clean_fight_count(debuffs_df, df, player_names, 2075, column_names=['duration'])
debuff_count.head()
# Out:
#     player  duration  fight_count primary_role
# 0  Acturus    153998           49       healer
# 1       Au    480556           27       damage
# 2   Ayriea   8304100           43       damage
# 3    Brian   5625392           49       damage
# 4   Bryiah   1297521           15       damage

# %%
longest_debuff_duration = la.find_count_order(debuff_count, 2, 'duration', least=False)
longest_debuff_duration
# Out:
#           player  duration  fight_count primary_role       av_count
# 10        Petrol  15103307           49       damage  308230.755102
# 9       Metonymy   9949922           48       damage  207290.041667
# 2         Ayriea   8304100           43       damage  193118.604651
# 14   Shadowbaine   6628025           38       damage  174421.710526
# 5         Future   6604258           48       damage  137588.708333
# 22      Èllipses   3551615           26       damage  136600.576923
# 8        Kyarrix   1542081           12       damage  128506.750000
# 3          Brian   5625392           49       damage  114803.918367
# 12         Pulsè    852793            8       damage  106599.125000
# 18  Undertakerop    175560            2       damage   87780.000000
# 4         Bryiah   1297521           15       damage   86501.400000
# 11   Psychodruid   3096711           41       damage   75529.536585
# 17      Tinytiki   2433008           34       damage   71559.058824
# ...

# %%
longest_debuff_duration.av_count = longest_debuff_duration.av_count/(60*1000)
longest_debuff_duration
# Out:
#           player  duration  fight_count primary_role  av_count
# 10        Petrol  15103307           49       damage  5.137179
# 9       Metonymy   9949922           48       damage  3.454834
# 2         Ayriea   8304100           43       damage  3.218643
# 14   Shadowbaine   6628025           38       damage  2.907029
# 5         Future   6604258           48       damage  2.293145
# 22      Èllipses   3551615           26       damage  2.276676
# 8        Kyarrix   1542081           12       damage  2.141779
# 3          Brian   5625392           49       damage  1.913399
# 12         Pulsè    852793            8       damage  1.776652
# 18  Undertakerop    175560            2       damage  1.463000
# 4         Bryiah   1297521           15       damage  1.441690
# 11   Psychodruid   3096711           41       damage  1.258826
# 17      Tinytiki   2433008           34       damage  1.192651
# 7          Kamer    744238           19       damage  0.652840
# ...

# %%
longest_debuff_duration.to_csv('guild_awards/eonar_debuff_duration.csv', encoding='iso-8859-1', index=False)

# %% [markdown]
# Total duration for Petrol (longest duration of the debuff)

# %%
petrol = longest_debuff_duration.query('player == "Petrol"').duration
petrol.loc[10]/(60*60*1000)
# Out:
# 4.195363055555555

# %% [markdown]
# Total duration for Met

# %%
met = longest_debuff_duration.query('player == "Metonymy"').duration
met.loc[9]/(60*60*1000)
# Out:
# 2.7638672222222223

# %%
yoked = longest_debuff_duration.query('player == "Yoked"').duration
yoked.loc[21]/(60*60*1000)
# Out:
# 0.07781416666666667

# %%
petrol.loc[10]/(60*60*1000) + met.loc[9]/(60*60*1000) + yoked.loc[21]/(60*60*1000)
# Out:
# 7.037044444444444

# %%
sns.distplot(longest_debuff_duration.av_count)
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# <a id='imonar'></a>
# ## Imonar

# %% [markdown]
# Boss ID: 2082

# %% [markdown]
# <a id='imonar-orbs'></a>
# ### Least damage from Conflag

# %% [markdown]
# **Spell IDs**
# - 250191
# - 248321

# %%
spell_id_250191 = wl.damage_taken(api_key, df, 250191, boss_id=2082)
# Out:
# ...
# Player added: Au
# Player added: Mythrose
# Player added: Earrl
# Player added: Vaelyra
# Player added: Cagliostro
# Player added: Shadowbaine
# Player added: Stradivarus
# Player added: Divanance
# Player added: Shallowfall
# Player added: Metonymy
# Player added: Brian
# Player added: Petrol
# Player added: Bryiah
# Player added: Psychodruid
# Player added: Illestra
# Player added: Radiantldeal
# Player added: Acturus
# Player added: Verle
# ...
# Player added: Illestra
# Player added: Kamer
# Player added: Velsummers
# Player added: Brian
# Player added: Vaelyra
# Player added: Cagliostro
# Player added: Stradivarus
# Player added: Mythrose
# Player added: Shallowfall
# Player added: Radiantldeal
# Player added: Petrol
# Player added: Earrl
# Player added: Uuglei
# ...
# Player added: Brian
# Player added: Divanance
# Player added: Illestra
# Player added: Psychodruid
# Player added: Acturus
# Player added: Undertakerop
# Player added: Cagliostro
# Player added: Shallowfall
# ...

# %%
spell_id_250191.head()
# Out:
#              log_id  spell_id      player  hits  damage_taken
# 0  7H6FtpVr9c4xaW8L    250191          Au     2      15116553
# 1  7H6FtpVr9c4xaW8L    250191    Mythrose     3      33563013
# 2  7H6FtpVr9c4xaW8L    250191       Earrl     5      29497080
# 3  7H6FtpVr9c4xaW8L    250191     Vaelyra     1       8566871
# 4  7H6FtpVr9c4xaW8L    250191  Cagliostro     3      25346952

# %%
spell_id_248321 = wl.damage_taken(api_key, df, 248321, boss_id=2082)
# Out:
# ...
# Player added: Illestra
# Player added: Stradivarus
# Player added: Shadowbaine
# Player added: Acturus
# Player added: Shallowfall
# Player added: Radiantldeal
# Player added: Psychodruid
# Player added: Mythrose
# Player added: Petrol
# Player added: Earrl
# Player added: Metonymy
# Player added: Au
# Player added: Brian
# Player added: Verle
# Player added: Cagliostro
# Player added: Bryiah
# Player added: Vaelyra
# Player added: Divanance
# ...
# Player added: Acturus
# Player added: Earrl
# Player added: Shallowfall
# Player added: Thebadlock
# Player added: Divanance
# Player added: Cagliostro
# Player added: Petrol
# Player added: Au
# Player added: Vaelyra
# Player added: Znoch
# Player added: Mythrose
# Player added: Psychodruid
# Player added: Metonymy
# Player added: Radiantldeal
# Player added: Brianmurican
# Player added: Zephyyra
# Player added: Illestra
# Player added: Googboog
# ...
# Player added: Psychodruid
# Player added: Vaelyra
# Player added: Ayriea
# Player added: Uuglei
# ...

# %%
spell_id_248321.head()
# Out:
#              log_id  spell_id       player  hits  damage_taken
# 0  7H6FtpVr9c4xaW8L    248321     Illestra     4       9746902
# 1  7H6FtpVr9c4xaW8L    248321  Stradivarus     1       2775379
# 2  7H6FtpVr9c4xaW8L    248321  Shadowbaine     1       2856662
# 3  7H6FtpVr9c4xaW8L    248321      Acturus     5      13471363
# 4  7H6FtpVr9c4xaW8L    248321  Shallowfall     2       5417117

# %%
conflag = pd.concat([spell_id_250191, spell_id_248321])

# %%
conflag.to_csv('guild_awards/imonar_conflag_data.csv', encoding='iso-8859-1', index=False)

# %% [markdown]
# Read in info

# %%
conflag = pd.read_csv('guild_awards/imonar_conflag_data.csv', encoding='iso-8859-1')

# %%
damage_taken = la.clean_fight_count(conflag, df, player_names, 2082, column_names=['hits', 'damage_taken'])

# %%
damage_taken = la.find_count_order(damage_taken, 30, 'hits')
damage_taken
# Out:
#           player  hits  damage_taken  fight_count primary_role  av_count
# 2         Ayriea    51     242150287          157       damage  0.324841
# 5     Cagliostro    51     263160964          154       damage  0.331169
# 32      Èllipses    43     194368087          122       damage  0.352459
# 3          Brian    55     264994725          155       damage  0.354839
# 28      Velryssa    28     121526363           74       damage  0.378378
# 21   Shadowbaine    55     290888468          134       damage  0.410448
# 27       Vaelyra    63     202556915          144       damage  0.437500
# 10      Googboog    25     126738845           52       damage  0.480769
# 17        Petrol    84     365718936          159       damage  0.528302
# 20  Radiantldeal    82     419426210          153       healer  0.535948
# 15      Metonymy    93     434280610          158       damage  0.588608
# 12         Kamer    55     237773545           86       damage  0.639535
# ...

# %%
damage_taken.to_csv('guild_awards/imonar_conflag_hits.csv', encoding='iso-8859-1', index=False)

# %%
sns.distplot(damage_taken.av_count);
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(damage_taken, col='primary_role').map(sns.distplot, "av_count");
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# <a id='imonar-dispels'></a>
# ### Dispels

# %% [markdown]
# **Spell IDs**
# - Priest: Purify (527), Mass Dispel (32375)
# - Paladin: Cleanse (4987)
# - Shaman: Purify Spirit (77130)

# %%
spell_ids = [32375, 4987, 77130]
dispel_df = wl.cast_count(api_key, df, 527, boss_id=2082)
for spell in spell_ids:
    spell_df = wl.cast_count(api_key, df, spell, boss_id=2082)
    dispel_df = pd.concat([dispel_df, spell_df])
# Out:
# ...
# Player added: Radiantldeal
# Player added: Mythrose
# ...
# Player added: Mythrose
# Player added: Radiantldeal
# ...
# Player added: Mythrose
# Player added: Radiantldeal
# ...
# Player added: Mythrose
# ...
# Player added: Radiantldeal
# ...
# Player added: Radiantldeal
# Player added: Mythrose
# ...
# Player added: Mythrose
# Player added: Radiantldeal
# ...
# Player added: Radiantldeal
# Player added: Mythrose
# ...
# Player added: Mythrose
# Player added: Radiantldeal
# ...
# Player added: Mythrose
# Player added: Radiantldeal
# ...
# Player added: Radiantldeal
# Player added: Mythrose
# ...
# Player added: Radiantldeal
# Player added: Mythrose
# ...
# Player added: Radiantldeal
# Player added: Mythrose
# ...
# Player added: Mythrose
# Player added: Radiantldeal
# ...
# Player added: Mythrose
# ...
# Player added: Radiantldeal
# ...
# Player added: Mythrose
# Player added: Radiantldeal
# ...
# Player added: Radiantldeal
# Player added: Mythrose
# ...
# Player added: Mythrose
# Player added: Radiantldeal
# ...
# Player added: Mythrose
# Player added: Radiantldeal
# ...

# %%
dispel_df.head()
# Out:
#              log_id  spell_id        player  count
# 0  7H6FtpVr9c4xaW8L       527  Radiantldeal     73
# 1  7H6FtpVr9c4xaW8L       527      Mythrose     73
# 2  82BfPKG7bpAjqLzh       527      Mythrose     27
# 3  82BfPKG7bpAjqLzh       527  Radiantldeal     34
# 4  9rzLcb8w6CWJAgfn       527      Mythrose     22

# %%
dispel_df.to_csv('guild_awards/imonar_dispel_data.csv', encoding='iso-8859-1', index=False)

# %% [markdown]
# Read in data

# %%
dispel_count = la.clean_fight_count(dispel_df, df, player_names, 2082, ['count'])

# %%
dispel_count.head()
# Out:
#          player  count  fight_count primary_role
# 0       Acturus    601          148       healer
# 1            Au     92           87       damage
# 2      Illestra    982          159       healer
# 3      Mythrose   1282          144       healer
# 4  Radiantldeal   1494          153       healer

# %%
dispel_count = la.find_count_order(dispel_count, 30, 'count', least=False)

# %%
dispel_count
# Out:
#          player  count  fight_count primary_role  av_count
# 4  Radiantldeal   1494          153       healer  9.764706
# 3      Mythrose   1282          144       healer  8.902778
# 2      Illestra    982          159       healer  6.176101
# 5      Zephyyra    555          105       healer  5.285714
# 0       Acturus    601          148       healer  4.060811
# 1            Au     92           87       damage  1.057471

# %%
dispel_count.to_csv('guild_awards/imonar_dispel_counts.csv', encoding='iso-8859-1', index=False)

# %%
sns.barplot(x='player', y='av_count', data=dispel_count);

# %% [markdown]
# <a id='kennyg'></a>
# ## Kin'Garoth

# %% [markdown]
# - Boss ID: 2088
# - Spell ID: 246779

# %%
orb_dam = wl.damage_taken(api_key, df, 246779, boss_id=2088)
# Out:
# ...
# Player added: Illestra
# Player added: Psychodruid
# Player added: Cagliostro
# Player added: Kamer
# Player added: Earrl
# Player added: Divanance
# Player added: Shallowfall
# Player added: Metonymy
# Player added: Ayriea
# Player added: Velryssa
# Player added: Acturus
# Player added: Radiantldeal
# Player added: Petrol
# Player added: Brian
# Player added: Mythrose
# Player added: Zephyyra
# Player added: Au
# Player added: Èllipses
# Player added: Vaelyra
# Player added: Znoch
# Player added: Bryiah
# ...
# Player added: Mythrose
# Player added: Velsummers
# Player added: Earrl
# Player added: Ayriea
# Player added: Psychodruid
# Player added: Radiantldeal
# Player added: Illestra
# Player added: Uuglei
# Player added: Tawñ
# Player added: Petrol
# Player added: Shallowfall
# Player added: Metonymy
# Player added: Shaami
# Player added: Katanescence
# Player added: Cagliostro
# Player added: Vaelyra
# Player added: Kamer
# Player added: Stradivarus
# Player added: Brian
# ...

# %%
orb_dam.head()
# Out:
#              log_id  spell_id       player  hits  damage_taken
# 0  2Vkpd7QhzTrCbqBg    246779     Illestra   204     337724616
# 1  2Vkpd7QhzTrCbqBg    246779  Psychodruid   198     340680251
# 2  2Vkpd7QhzTrCbqBg    246779   Cagliostro   214     387133960
# 3  2Vkpd7QhzTrCbqBg    246779        Kamer   199     329121402
# 4  2Vkpd7QhzTrCbqBg    246779        Earrl   215     365998049

# %%
orb_dam.to_csv('guild_awards/kingaroth_org_data.csv', encoding='iso-8859-1', index=False)

# %%
least_damage = la.clean_fight_count(orb_dam, df, player_names, 2088, ['hits', 'damage_taken'])
least_damage = la.find_count_order(least_damage, 80, 'damage_taken')
least_damage
# Out:
#           player  hits  damage_taken  fight_count primary_role      av_count
# 22   Shallowfall  1752    2572457788           90       damage  2.858286e+07
# 28       Vaelyra  1719    2812442538           89       damage  3.160048e+07
# 17   Psychodruid  1729    2987832523           92       damage  3.247644e+07
# 8          Earrl  2071    3509951585          104         tank  3.374953e+07
# 3          Brian  1853    3315346166           98       damage  3.383006e+07
# 19  Radiantldeal  1642    2811727905           81       healer  3.471269e+07
# 5     Cagliostro  1768    3270601112           94       damage  3.479363e+07
# 32      Èllipses  1735    3158965243           90       damage  3.509961e+07
# 10      Illestra  2062    3692491624          104       healer  3.550473e+07
# 25      Tinytiki  1648    2913624209           82       damage  3.553200e+07
# 9         Future  1682    3009502065           84       damage  3.582741e+07
# ...

# %%
least_damage.to_csv('guild_awards/kingaroth_orb_damage.csv', encoding='iso-8859-1', index=False)

# %%
sns.distplot(least_damage.av_count);
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(least_damage, col='primary_role').map(sns.distplot, "av_count");
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# <a id='vari'></a>
# ## Varimathras

# %% [markdown]
# Boss ID: 2069

# %%
add_damage = damage_done(api_key, df, 2069)
# Out:
# ...
# Player added: Shallowfall
# Player added: Psychodruid
# Player added: Pulsè
# Player added: Vaelyra
# Player added: Zephyyra
# Player added: Velryssa
# Player added: Tinytiki
# Player added: Shadowbaine
# Player added: Cagliostro
# Player added: Acturus
# Player added: Stradivarus
# Player added: Radiantldeal
# Player added: Brian
# Player added: Mythrose
# Player added: Metonymy
# Player added: Petrol
# Player added: Future
# Player added: Kyarrix
# Player added: Earrl
# Player added: Divanance
# Player added: Illestra
# ...
# Player added: Radiantldeal
# Player added: Ayriea
# Player added: Pulsè
# Player added: Mythrose
# Player added: Au
# Player added: Acturus
# Player added: Future
# Player added: Earrl
# Player added: Bryiah
# Player added: Brian
# Player added: Shallowfall
# Player added: Stradivarus
# Player added: Illestra
# Player added: Metonymy
# Player added: Vaelyra
# Player added: Cagliostro
# Player added: Divanance
# Player added: Petrol
# Player added: Velryssa
# ...

# %%
add_damage.head()
# Out:
#              log_id       player   NPC  damage_done
# 0  1q8V234wXDhrRakC  Shallowfall  True    234541394
# 1  1q8V234wXDhrRakC  Psychodruid  True    282751871
# 2  1q8V234wXDhrRakC        Pulsè  True     66095722
# 3  1q8V234wXDhrRakC      Vaelyra  True    149123433
# 4  1q8V234wXDhrRakC     Zephyyra  True      2474764

# %%
add_damage.to_csv('guild_awards/varimathras_add_data.csv', encoding='iso-8859-1', index=False)

# %% [markdown]
# Read in info

# %%
add_damage = pd.read_csv('guild_awards/varimathras_add_data.csv', encoding='iso-8859-1')

# %%
damage_done = la.clean_fight_count(add_damage, df, player_names, 2069, ['damage_done'])
damage_done = la.find_count_order(damage_done, 30, 'damage_done', least=False)
damage_done
# Out:
#           player  damage_done  fight_count primary_role      av_count
# 9         Future   6477298097          167       damage  3.878622e+07
# 1             Au   3435115289          104       damage  3.302995e+07
# 16        Petrol   5402439012          185       damage  2.920237e+07
# 14      Metonymy   4603082695          170       damage  2.707696e+07
# 17   Psychodruid   3612695036          162       damage  2.230059e+07
# 4         Bryiah   1814133362           84       damage  2.159683e+07
# 23   Stradivarus   2003491027           99       damage  2.023728e+07
# 22   Shallowfall   3277634433          170       damage  1.928020e+07
# 3          Brian   2515923658          172       damage  1.462746e+07
# 28       Vaelyra   2189777461          185       damage  1.183663e+07
# 25      Tinytiki   1555334408          138       damage  1.127054e+07
# 29      Velryssa    814206685           79       damage  1.030641e+07
# ...

# %%
damage_done.to_csv('guild_awards/varimathras_add_damage.csv', encoding='iso-8859-1', index=True)

# %% [markdown]
# <a id='coven'></a>
# ## Coven

# %% [markdown]
# Boss ID: 2073

# %% [markdown]
# <a id='coven-glare'></a>
# ### Least Cosmic Glare Damage

# %% [markdown]
# Spell ID: 250912

# %%
glare = wl.damage_taken(api_key, df, 250912, 'Cosmic Glare', 2073)
# Out:
# ...
# Player added: Brian
# Player added: Earrl
# Player added: Velryssa
# Player added: Kyarrix
# Player added: Cagliostro
# Player added: Divanance
# Player added: Stradivarus
# ...
# Player added: Vaelyra
# Player added: Radiantldeal
# Player added: Metonymy
# Player added: Cagliostro
# Player added: Brian
# Player added: Earrl
# Player added: Mythrose
# Player added: Ayriea
# Player added: Pulsè
# Player added: Psychodruid
# Player added: Future
# Player added: Petrol
# Player added: Illestra
# ...
# Player added: Vaelyra
# Player added: Divanance
# Player added: Uuglei
# Player added: Petrol
# Player added: Velsummers
# Player added: Illestra
# Player added: Brian
# Player added: Psychodruid
# Player added: Shallowfall
# Player added: Shadowbaine
# Player added: Tawñ
# Player added: Earrl
# Player added: Mythrose
# Player added: Stradivarus
# Player added: Katanescence
# Player added: Kamer
# Player added: Radiantldeal
# Player added: Metonymy
# Player added: Ayriea
# Player added: Cagliostro
# ...

# %%
glare.head()
# Out:
#              log_id  spell_id    spell_name      player  hits  damage_taken
# 0  1q8V234wXDhrRakC    250912  Cosmic Glare       Brian     1       4435279
# 1  1q8V234wXDhrRakC    250912  Cosmic Glare       Earrl     1       2791495
# 2  1q8V234wXDhrRakC    250912  Cosmic Glare    Velryssa     1       3735884
# 3  1q8V234wXDhrRakC    250912  Cosmic Glare     Kyarrix     1       4281666
# 4  1q8V234wXDhrRakC    250912  Cosmic Glare  Cagliostro     1       4522887

# %%
glare.to_csv('guild_awards/coven_glare_data.csv', encoding='iso-8859-1', index=False)

# %% [markdown]
# Read in info

# %%
glare = pd.read_csv('guild_awards/coven_glare_data.csv', encoding='iso-8859-1')

# %%
glare_damage = la.clean_fight_count(glare, df, player_names, 2073, ['hits', 'damage_taken'])
glare_damage = la.find_count_order(glare_damage, 30, 'hits')
glare_damage
# Out:
#           player  hits  damage_taken  fight_count primary_role  av_count
# 6      Divanance    20      61884393           69         tank  0.289855
# 7          Earrl    22      68046689           69         tank  0.318841
# 3          Brian    24     104496861           69       damage  0.347826
# 2         Ayriea    28     121880035           67       damage  0.417910
# 26       Vaelyra    27     101368098           64       damage  0.421875
# 4     Cagliostro    27     114652162           64       damage  0.421875
# 0        Acturus    32     137605433           63       healer  0.507937
# 15        Petrol    36     160271270           69       damage  0.521739
# 20   Shallowfall    32      94747030           61       damage  0.524590
# 29      Èllipses    20      81350848           37       damage  0.540541
# 8         Future    37     156405990           63       damage  0.587302
# 9       Illestra    41     156120309           69       healer  0.594203
# ...

# %%
glare_damage.to_csv('guild_awards/coven_glare_damage.csv', encoding='iso-8859-1', index=False)

# %%
sns.distplot(glare_damage.av_count);
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(glare_damage, col='primary_role').map(sns.distplot, "av_count");
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# <a id='coven-blades'></a>
# ### Least Shadow Blades Damage

# %% [markdown]
# Spell ID: 246374

# %%
blades = wl.damage_taken(api_key, df, 246374, 'Shadow Blades', 2073)
# Out:
# ...
# Player added: Shadowbaine
# Player added: Illestra
# Player added: Psychodruid
# Player added: Kyarrix
# Player added: Ayriea
# Player added: Radiantldeal
# Player added: Velryssa
# Player added: Future
# Player added: Shallowfall
# ...
# Player added: Earrl
# Player added: Pulsè
# Player added: Acturus
# Player added: Petrol
# Player added: Psychodruid
# Player added: Metonymy
# Player added: Stradivarus
# Player added: Brian
# Player added: Illestra
# Player added: Au
# Player added: Vaelyra
# Player added: Shallowfall
# Player added: Èllipses
# Player added: Divanance
# Player added: Future
# Player added: Radiantldeal
# Player added: Mythrose
# Player added: Cagliostro
# Player added: Shadowbaine
# Player added: Ayriea
# ...
# Player added: Stradivarus
# Player added: Mythrose
# Player added: Shallowfall
# Player added: Katanescence
# Player added: Vaelyra
# Player added: Tawñ
# Player added: Kamer
# Player added: Radiantldeal
# Player added: Illestra
# Player added: Psychodruid
# ...

# %%
blades.head()
# Out:
#              log_id  spell_id     spell_name       player  hits  damage_taken
# 0  1q8V234wXDhrRakC    246374  Shadow Blades  Shadowbaine     1       4672874
# 1  1q8V234wXDhrRakC    246374  Shadow Blades     Illestra     2       8173346
# 2  1q8V234wXDhrRakC    246374  Shadow Blades  Psychodruid     2       7998373
# 3  1q8V234wXDhrRakC    246374  Shadow Blades      Kyarrix     1       4120006
# 4  1q8V234wXDhrRakC    246374  Shadow Blades       Ayriea     1       4475254

# %%
blades.to_csv('guild_awards/coven_blades_data.csv', encoding='iso-8859-1', index=False)

# %%
blade_damage = la.clean_fight_count(blades, df, player_names, 2073, ['hits', 'damage_taken'])
blade_damage = la.find_count_order(blade_damage, 10, 'hits')
blade_damage
# Out:
#           player  hits  damage_taken  fight_count primary_role  av_count
# 21   Stradivarus    10      48340726           60       damage  0.166667
# 2         Ayriea    15      66656233           67       damage  0.223881
# 6      Divanance    18      54506495           69         tank  0.260870
# 8         Future    17      70075937           63       damage  0.269841
# 5          Daffy     4      16101287           14       healer  0.285714
# 14      Mythrose    20      86866807           69       healer  0.289855
# 4     Cagliostro    19      81291669           64       damage  0.296875
# 29      Èllipses    11      44678202           37       damage  0.297297
# 7          Earrl    22      62309580           69         tank  0.318841
# 15        Petrol    22      99278345           69       damage  0.318841
# 3          Brian    26     112594798           69       damage  0.376812
# 17         Pulsè    24      98284099           63       damage  0.380952
# ...

# %%
blade_damage.to_csv('guild_awards/coven_blade_damage.csv', encoding='iso-8859-1', index=False)

# %%
sns.distplot(blade_damage.av_count);
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(blade_damage, col='primary_role').map(sns.distplot, "av_count");
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# <a id='coven-storm'></a>
# ### Least Storm Damage

# %% [markdown]
# Spell ID: 253020

# %%
df.query('log_id == "kL7rz9c3RaAtNPGx"').pull_end.max()
# Out:
# 10358759

# %%
storm = wl.damage_taken(api_key, df, 253020, 'Storm of Darkness', 2073)
# Out:
# ...
# Player added: Future
# Player added: Metonymy
# Player added: Stradivarus
# Player added: Divanance
# Player added: Illestra
# Player added: Cagliostro
# Player added: Shadowbaine
# Player added: Psychodruid
# Player added: Petrol
# Player added: Mythrose
# Player added: Brian
# Player added: Kyarrix
# Player added: Ayriea
# Player added: Acturus
# Player added: Pulsè
# Player added: Earrl
# Player added: Vaelyra
# Player added: Velryssa
# Player added: Radiantldeal
# Player added: Shallowfall
# ...
# Player added: Brian
# Player added: Petrol
# Player added: Radiantldeal
# Player added: Future
# Player added: Acturus
# Player added: Au
# Player added: Illestra
# Player added: Shallowfall
# Player added: Psychodruid
# Player added: Vaelyra
# Player added: Cagliostro
# Player added: Divanance
# Player added: Metonymy
# Player added: Shadowbaine
# Player added: Èllipses
# Player added: Ayriea
# Player added: Stradivarus
# Player added: Mythrose
# Player added: Earrl
# Player added: Pulsè
# ...

# %%
storm.head()
# Out:
#              log_id  spell_id         spell_name       player  hits  \
# 0  1q8V234wXDhrRakC    253020  Storm of Darkness       Future     0
# 1  1q8V234wXDhrRakC    253020  Storm of Darkness     Metonymy     0
# 2  1q8V234wXDhrRakC    253020  Storm of Darkness  Stradivarus     0
# 3  1q8V234wXDhrRakC    253020  Storm of Darkness    Divanance     0
# 4  1q8V234wXDhrRakC    253020  Storm of Darkness     Illestra     0
#
#    damage_taken
# 0      12581045
# 1       7857425
# 2       8877456
# 3      26331931
# 4       1872533

# %%
storm.to_csv('guild_awards/coven_storm_data.csv', encoding='iso-8859-1', index=False)

# %%
storm_damage = la.clean_fight_count(storm, df, player_names, 2073, ['hits', 'damage_taken'])
storm_damage = la.find_count_order(storm_damage, 30, 'damage_taken')
storm_damage
# Out:
#           player  hits  damage_taken  fight_count primary_role      av_count
# 2         Ayriea     0     266664110           67       damage  3.980061e+06
# 9         Future     0     279377496           63       damage  4.434563e+06
# 14      Metonymy     0     315778083           69       damage  4.576494e+06
# 16        Petrol     0     359880168           69       damage  5.215655e+06
# 15      Mythrose     0     363488408           69       healer  5.267948e+06
# 3          Brian     0     408673471           69       damage  5.922804e+06
# 5     Cagliostro     0     421023833           64       damage  6.578497e+06
# 10      Illestra     0     478804263           69       healer  6.939192e+06
# 0        Acturus     0     450244449           63       healer  7.146737e+06
# 18         Pulsè     0     467333272           63       damage  7.417988e+06
# 17   Psychodruid     0     432834472           56       damage  7.729187e+06
# ...

# %%
storm_damage.to_csv('guild_awards/coven_storm_damage.csv', encoding='iso-8859-1', index=False)

# %%
sns.distplot(storm_damage.av_count);
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(storm_damage, col='primary_role').map(sns.distplot, "av_count");
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# <a id='coven-cc'></a>
# ### Most Add CC Casts

# %% [markdown]
# **Spell IDs**
# - Mage: Counterspell (2139), Dragon's Breath (31661), Frost Nova (122)
# - Druid: Solar Beam (78675), Typhoon (61391), Entangling Roots (339), Mass Entanglement (102359), Skull Bash (106839)
# - Warrior: Pummel (6552), Intimidating Shout (5246), Hamstring (1715), Piercing Howl (12323)
# - Hunter: Counter Shot (147362), Concussive Shot (5116), Freezing Trap (187650), Tar Trap (187698), Wyvern Sting (19386)
# - DK: Mind Freeze (47528), Death Grip (49576), Gorefiend's Grasp (108199)
# - Rogue: Kick (1766), Kidney Shot (408)
# - DH: Consume Magic (183752)
# - Shaman: Wind Shear (57994), Lightning/Cap Totem (192058), Earthgrab Totem (51485)
# - Paladin: Rebuke (96231), Hammer of Justice (853)
# - Warlock: Banish (710), Shadow Lock (171140)

# %%
cc_ids = [2139, 31661, 122, 78675, 61391, 339, 102359, 106839, 6552, 5246, 1715, 12323, 147362, 5116, 187650, 187698, 19386,
          47528, 49576, 108199, 1766, 408, 183752, 57994, 192058, 51485, 96231, 853, 710, 171140]

# %%
len(cc_ids)
# Out:
# 30

# %%
cc_casts = wl.cast_count(api_key, df, 2139, boss_id=2073)
# Out:
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Petrol
# Player added: Tawñ
# Player added: Metonymy
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Petrol
# Player added: Metonymy
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Petrol
# Player added: Metonymy
# ...
# Player added: Petrol
# Player added: Metonymy
# ...
# Player added: Petrol
# Player added: Metonymy

# %%
for spell in cc_ids[1:10]:
    try:
        print('Spell ID:', spell)
        spell_df = wl.cast_count(api_key, df, spell, boss_id=2073)
        cc_casts = pd.concat([cc_casts, spell_df])
    except:
        continue
# Out:
# Spell ID: 31661
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Petrol
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Petrol
# ...
# Player added: Petrol
# Player added: Metonymy
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Petrol
# Spell ID: 122
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Tawñ
# Player added: Petrol
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Petrol
# ...
# Player added: Petrol
# Player added: Metonymy
# ...
# Player added: Metonymy
# Player added: Petrol
# ...
# Player added: Petrol
# Spell ID: 78675
# ...
# Player added: Velsummers
# Player added: Psychodruid
# ...
# Player added: Psychodruid
# ...
# Player added: Psychodruid
# ...
# Player added: Psychodruid
# ...
# Spell ID: 61391
# ...
# Spell ID: 339
# ...
# Player added: Psychodruid
# ...
# Player added: Psychodruid
# Player added: Earrl
# ...
# Player added: Psychodruid
# Player added: Earrl
# ...

# %%
for spell in cc_ids[10:20]:
    try:
        print('Spell ID:', spell)
        spell_df = wl.cast_count(api_key, df, spell, boss_id=2073)
        cc_casts = pd.concat([cc_casts, spell_df])
    except:
        continue
# Out:
# Spell ID: 1715
# ...
# Player added: Cagliostro
# ...
# Player added: Cagliostro
# ...
# Player added: Cagliostro
# ...
# Player added: Cagliostro
# ...
# Player added: Cagliostro
# ...
# Player added: Cagliostro
# ...
# Player added: Cagliostro
# Spell ID: 12323
# ...
# Player added: Stradivarus
# ...
# Player added: Stradivarus
# ...
# Player added: Stradivarus
# ...
# Player added: Stradivarus
# ...
# Player added: Stradivarus
# Spell ID: 147362
# ...
# Player added: Ayriea
# Player added: Brian
# ...
# Player added: Ayriea
# Player added: Brian
# ...
# Player added: Ayriea
# Player added: Brian
# ...
# Player added: Brian
# Player added: Ayriea
# ...
# Player added: Ayriea
# Player added: Brian
# ...
# Player added: Ayriea
# Player added: Brian
# ...
# Player added: Brian
# Player added: Ayriea
# Spell ID: 5116
# ...
# Player added: Ayriea
# ...
# Player added: Ayriea
# ...
# Player added: Ayriea
# ...
# Player added: Brian
# ...
# Spell ID: 187650
# ...
# Player added: Kyarrix
# Player added: Ayriea
# ...
# Player added: Brian
# Player added: Ayriea
# ...
# Player added: Ayriea
# Player added: Brian
# ...
# Player added: Ayriea
# ...

# %%
for spell in cc_ids[20:]:
    try:
        print('Spell ID:', spell)
        spell_df = wl.cast_count(api_key, df, spell, boss_id=2073)
        cc_casts = pd.concat([cc_casts, spell_df])
    except:
        continue
# Out:
# Spell ID: 1766
# ...
# Spell ID: 408
# ...
# Spell ID: 183752
# ...
# Player added: Vaelyra
# ...
# Player added: Vaelyra
# ...
# Player added: Vaelyra
# ...
# Player added: Vaelyra
# ...
# Player added: Vaelyra
# Spell ID: 57994
# ...
# Player added: Future
# ...
# Player added: Future
# Player added: Illestra
# ...
# Player added: Future
# ...
# Player added: Future
# ...
# Player added: Future
# ...
# Player added: Future
# ...
# Player added: Future
# ...
# Player added: Future
# Spell ID: 192058
# ...
# Player added: Illestra
# ...
# Player added: Illestra
# ...
# Player added: Illestra
# ...
# Player added: Future
# Player added: Illestra
# ...
# Player added: Future
# Player added: Illestra
# ...
# Player added: Illestra
# ...
# Player added: Illestra
# ...
# Player added: Illestra
# ...
# Player added: Illestra
# Spell ID: 51485
# ...
# Player added: Future
# ...
# Player added: Future
# ...
# Player added: Future
# ...
# Player added: Future
# ...
# Player added: Future
# Player added: Illestra
# ...
# Player added: Future
# Spell ID: 96231
# ...
# Player added: Uuglei
# Player added: Kamer
# ...
# Player added: Au
# ...
# Player added: Acturus
# Player added: Au
# ...

# %%
cc_casts.head()
# Out:
#              log_id spell_id    player count
# 0  1q8V234wXDhrRakC     2139  Metonymy     1
# 1  1q8V234wXDhrRakC     2139    Petrol     1
# 2  1VNCD6KjrLg2wFGY     2139  Metonymy     1
# 3  1VNCD6KjrLg2wFGY     2139    Petrol     1
# 4  9rzLcb8w6CWJAgfn     2139    Petrol    10

# %%
cc_casts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 299 entries, 0 to 6
# Data columns (total 4 columns):
# log_id      299 non-null object
# spell_id    299 non-null object
# player      299 non-null object
# count       299 non-null object
# dtypes: object(4)
# memory usage: 11.7+ KB

# %%
cc_casts.nunique()
# Out:
# log_id       9
# spell_id    27
# player      25
# count       19
# dtype: int64

# %%
cc_casts.to_csv('guild_awards/coven_cc_data.csv', encoding='iso-8859-1', index=False)

# %%
cc_count = la.clean_fight_count(cc_casts, df, player_names, 2073, ['count'])
cc_count = la.find_count_order(cc_count, 30, 'count', least=False)
cc_count
# Out:
#          player  count  fight_count primary_role  av_count
# 2        Ayriea    217           67       damage  3.238806
# 7         Earrl    211           69         tank  3.057971
# 3         Brian    196           69       damage  2.840580
# 13       Petrol    164           69       damage  2.376812
# 18  Stradivarus    116           60       damage  1.933333
# 14  Psychodruid    103           56       damage  1.839286
# 8        Future    114           63       damage  1.809524
# 6     Divanance    112           69         tank  1.623188
# 16  Shadowbaine    105           69       damage  1.521739
# 12     Metonymy    102           69       damage  1.478261
# 24     Èllipses     41           37       damage  1.108108
# 1            Au     42           40       damage  1.050000
# 15        Pulsè     66           63       damage  1.047619
# 4    Cagliostro     52           64       damage  0.812500
# 17  Shallowfall     43           61       damage  0.704918
# ...

# %%
cc_count.to_csv('guild_awards/coven_cc_counts.csv', encoding='iso-8859-1', index=False)

# %% [markdown]
# <a id='agg'></a>
# ## Aggramar

# %% [markdown]
# - Boss ID: 2063
# - Spell ID (Ravenous Blaze): 254452

# %%
blaze = wl.damage_taken(api_key, df, 254452, 'Ravenous Blaze', 2063)
# Out:
# ...
# Player added: Mythrose
# Player added: Ayriea
# Player added: Èllipses
# Player added: Illestra
# Player added: Shadowbaine
# Player added: Radiantldeal
# Player added: Brian
# Player added: Acturus
# Player added: Petrol
# Player added: Future
# Player added: Pulsè
# Player added: Metonymy
# Player added: Psychodruid
# Player added: Zephyyra
# ...
# Player added: Future
# Player added: Daffy
# Player added: Brian
# Player added: Pulsè
# Player added: Metonymy
# Player added: Au
# Player added: Psychodruid
# Player added: Petrol
# Player added: Radiantldeal
# Player added: Ayriea
# Player added: Mythrose
# Player added: Illestra
# ...
# Player added: Mythrose
# Player added: Future
# Player added: Psychodruid
# Player added: Daffy
# Player added: Divanance
# Player added: Radiantldeal
# Player added: Illestra
# Player added: Ayriea
# Player added: Shallowfall
# Player added: Brian
# Player added: Metonymy
# Player added: Petrol
# Player added: Pulsè
# Player added: Shadowbaine
# ...

# %%
blaze.head()
# Out:
#              log_id  spell_id      spell_name       player  hits  damage_taken
# 0  26gRPafVjHzvLQFN    254452  Ravenous Blaze     Mythrose     0      88624888
# 1  26gRPafVjHzvLQFN    254452  Ravenous Blaze       Ayriea     0      64503123
# 2  26gRPafVjHzvLQFN    254452  Ravenous Blaze     Èllipses     0      61693458
# 3  26gRPafVjHzvLQFN    254452  Ravenous Blaze     Illestra     0     100323468
# 4  26gRPafVjHzvLQFN    254452  Ravenous Blaze  Shadowbaine     0     110758333

# %%
blaze.to_csv('guild_awards/aggramar_blaze_data.csv', encoding='iso-8859-1', index=False)

# %%
blaze = pd.read_csv('guild_awards/aggramar_blaze_data.csv', encoding='iso-8859-1')

# %%
blaze_damage = la.clean_fight_count(blaze, df, player_names, 2063, ['damage_taken'])
blaze_damage = la.find_count_order(blaze_damage, 30, 'damage_taken')
blaze_damage
# Out:
#           player  damage_taken  fight_count primary_role      av_count
# 6          Earrl       1522113          262         tank  5.809592e+03
# 19   Stradivarus       3668173          251       damage  1.461424e+04
# 5      Divanance       5961565          262         tank  2.275406e+04
# 18   Shallowfall      12260285          262       damage  4.679498e+04
# 1             Au       9179723          191       damage  4.806138e+04
# 0        Acturus      19234342          262       healer  7.341352e+04
# 22      Zephyyra     459523650           67       healer  6.858562e+06
# 14         Pulsè    1191200412          143       damage  8.330073e+06
# 3          Brian    2367412089          262       damage  9.035924e+06
# 13   Psychodruid    1826819463          200       damage  9.134097e+06
# 8       Illestra    2307800145          243       healer  9.497120e+06
# 10      Metonymy    2492929461          262       damage  9.514998e+06
# ...

# %%
blaze_damage.to_csv('guild_awards/aggramar_blaze_damage.csv', encoding='iso-8859-1', index=False)

# %% [markdown]
# ### Most Hits of Empowered Flame Rend

# %% [markdown]
# Spell ID: 247079

# %%
rend = wl.damage_taken(api_key, df, 247079, 'Ravenous Blaze', 2063)
# Out:
# ...
# Player added: Illestra
# Player added: Divanance
# Player added: Èllipses
# Player added: Acturus
# Player added: Ayriea
# Player added: Zephyyra
# Player added: Shadowbaine
# Player added: Radiantldeal
# Player added: Metonymy
# Player added: Velryssa
# Player added: Mythrose
# Player added: Brian
# Player added: Cagliostro
# Player added: Pulsè
# Player added: Psychodruid
# Player added: Shallowfall
# Player added: Stradivarus
# Player added: Au
# Player added: Future
# Player added: Petrol
# Player added: Earrl
# ...
# Player added: Mythrose
# Player added: Acturus
# Player added: Pulsè
# Player added: Psychodruid
# Player added: Illestra
# Player added: Daffy
# Player added: Earrl
# Player added: Vaelyra
# Player added: Petrol
# Player added: Stradivarus
# Player added: Tinytiki
# Player added: Cagliostro
# Player added: Ayriea
# Player added: Velryssa
# Player added: Future
# Player added: Metonymy
# Player added: Divanance
# Player added: Radiantldeal
# Player added: Au
# ...

# %%
rend.head()
# Out:
#              log_id  spell_id      spell_name     player  hits  damage_taken
# 0  26gRPafVjHzvLQFN    247079  Ravenous Blaze   Illestra    11      42404203
# 1  26gRPafVjHzvLQFN    247079  Ravenous Blaze  Divanance    24     212693413
# 2  26gRPafVjHzvLQFN    247079  Ravenous Blaze   Èllipses    11     162941641
# 3  26gRPafVjHzvLQFN    247079  Ravenous Blaze    Acturus    22     187049509
# 4  26gRPafVjHzvLQFN    247079  Ravenous Blaze     Ayriea    11      73725594

# %%
rend.to_csv('guild_awards/aggramar_rend_data.csv', encoding='iso-8859-1', index=False)

# %%
rend_damage = la.clean_fight_count(rend, df, player_names, 2063, ['hits', 'damage_taken'])
rend_damage = la.find_count_order(rend_damage, 100, 'hits', least=False)
rend_damage
# Out:
#           player  hits  damage_taken  fight_count primary_role  av_count
# 6      Divanance   631    7804351746          262         tank  2.408397
# 25       Vaelyra   512    2316947333          224       damage  2.285714
# 26      Velryssa   295    1568599828          132       damage  2.234848
# 4     Cagliostro   535    2543288274          242       damage  2.210744
# 21   Stradivarus   551    3799002551          251       damage  2.195219
# 0        Acturus   574    3831196961          262       healer  2.190840
# 20   Shallowfall   571    4220536377          262       damage  2.179389
# 12      Metonymy   515    3195250171          262       damage  1.965649
# 7          Earrl   505    4433677650          262         tank  1.927481
# 1             Au   347    2034251379          191       damage  1.816754
# 14        Petrol   447    2210635412          262       damage  1.706107
# 5          Daffy   234     870621548          146       healer  1.602740
# ...

# %%
rend_damage.to_csv('guild_awards/aggramar_rend_damage.csv', encoding='iso-8859-1', index=False)

# %%
sns.distplot(rend_damage.av_count);
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(rend_damage, col='primary_role').map(sns.distplot, "av_count");
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# <a id='argus'></a>
# ## Argus

# %% [markdown]
# Boss ID: 2092

# %%
argus_logs = df.query('boss_name == "Argus the Unmaker"').sort_values('log_start', ascending=False)[['log_id', 'log_start']]

# %%
argus_logs.drop_duplicates(inplace=True)

# %%
after_break = argus_logs.head(13)
after_break
# Out:
#                  log_id     log_start
# 11541  Cf129KrpDWPXT7xz  1.531275e+12
# 27341  tnmFjCNGXJgVZYTz  1.531188e+12
# 28888  VhmB61LqvrRQPFwJ  1.530152e+12
# 12177  cR4g7wGY2z9VWbxH  1.530064e+12
# 21833  nRG1BJmD6fhC2vNq  1.529633e+12
# 27814  Tvrh8BgQL6y2qPza  1.529546e+12
# 10197  Bqr8ZpYX6AV2cynW  1.529461e+12
# 23524  qRpvXcKG6NAaDCJ4  1.529030e+12
# 5083   8QYh3aAXpgPLjydJ  1.528942e+12
# 2456   2cVBtJTgC1KLn7Am  1.528855e+12
# 25165  rHCXbP8aVj72DQAY  1.528423e+12
# 11090  C8VnGm3qW9Ldzwvg  1.528337e+12
# 11740  cNbjQKh89RxWVPDp  1.528250e+12

# %%
break_logs = list(after_break.log_id)
break_logs
# Out:
# ['Cf129KrpDWPXT7xz',
#  'tnmFjCNGXJgVZYTz',
#  'VhmB61LqvrRQPFwJ',
#  'cR4g7wGY2z9VWbxH',
#  'nRG1BJmD6fhC2vNq',
#  'Tvrh8BgQL6y2qPza',
#  'Bqr8ZpYX6AV2cynW',
#  'qRpvXcKG6NAaDCJ4',
#  '8QYh3aAXpgPLjydJ',
#  '2cVBtJTgC1KLn7Am',
#  'rHCXbP8aVj72DQAY',
#  'C8VnGm3qW9Ldzwvg',
#  'cNbjQKh89RxWVPDp']

# %%
argus_after_break = df[df.log_id.isin(break_logs)]
argus_after_break.head()
# Out:
#                 log_id     log_start       log_end  pull_id  pull_start  \
# 2451  2cVBtJTgC1KLn7Am  1.528855e+12  1.528865e+12        1     1349893
# 2452  2cVBtJTgC1KLn7Am  1.528855e+12  1.528865e+12        1     1349893
# 2453  2cVBtJTgC1KLn7Am  1.528855e+12  1.528865e+12        1     1349893
# 2454  2cVBtJTgC1KLn7Am  1.528855e+12  1.528865e+12        1     1349893
# 2455  2cVBtJTgC1KLn7Am  1.528855e+12  1.528865e+12        1     1349893
#
#       pull_end  boss_id          boss_name   kill player_name
# 2451   1406867     2092  Argus the Unmaker  False    Metonymy
# 2452   1406867     2092  Argus the Unmaker  False   Divanance
# 2453   1406867     2092  Argus the Unmaker  False      Petrol
# 2454   1406867     2092  Argus the Unmaker  False  Cagliostro
# 2455   1406867     2092  Argus the Unmaker  False      Ayriea

# %% [markdown]
# <a id='argus-fear'></a>
# ### Least Crushing Fear Damage

# %% [markdown]
# Spell ID: 257930

# %%
fear = wl.damage_taken(api_key, argus_after_break, 257930, 'Crushing Fear', 2092)
# Out:
# ...
# Player added: Metonymy
# Player added: Mythrose
# Player added: Velryssa
# Player added: Shadowbaine
# Player added: Ayriea
# Player added: Shaami
# Player added: Velsummers
# Player added: Uuglei
# Player added: Petrol
# Player added: Cagliostro
# Player added: Brian
# Player added: Acturus
# Player added: Tawñ
# Player added: Vaelyra
# Player added: Kamer
# Player added: Radiantldeal
# Player added: Illestra
# Player added: Eleint
# ...
# Player added: Shaami
# Player added: Ayriea
# Player added: Radiantldeal
# Player added: Kamer
# Player added: Psychodruid
# Player added: Uuglei
# Player added: Brian
# Player added: Acturus
# Player added: Metonymy
# Player added: Tawñ
# Player added: Eleint
# Player added: Cagliostro
# Player added: Mythrose
# Player added: Illestra
# Player added: Shadowbaine
# Player added: Velsummers
# Player added: Vaelyra
# Player added: Petrol
# ...
# Player added: Illestra
# Player added: Shaami
# Player added: Petrol
# Player added: Acturus
# ...

# %%
fear.head()
# Out:
#              log_id  spell_id     spell_name       player  hits  damage_taken
# 0  2cVBtJTgC1KLn7Am    257930  Crushing Fear     Metonymy     0     140387418
# 1  2cVBtJTgC1KLn7Am    257930  Crushing Fear     Mythrose     0     178359278
# 2  2cVBtJTgC1KLn7Am    257930  Crushing Fear     Velryssa     0      42418318
# 3  2cVBtJTgC1KLn7Am    257930  Crushing Fear  Shadowbaine     0     173418321
# 4  2cVBtJTgC1KLn7Am    257930  Crushing Fear       Ayriea     0     284727678

# %%
fear.to_csv('guild_awards/argus_fear_data_after.csv', encoding='iso-8859-1', index=False)

# %% [markdown]
# Read in info

# %%
fear = pd.read_csv('guild_awards/argus_fear_data_after.csv', encoding='iso-8859-1')

# %%
fear_damage = la.clean_fight_count(fear, argus_after_break, player_names, 2092, ['damage_taken'])
fear_damage = la.find_count_order(fear_damage, 100, 'damage_taken')
fear_damage
# Out:
#           player  damage_taken  fight_count primary_role      av_count
# 13   Psychodruid     810607728          259       damage  3.129760e+06
# 6         Eleint    1324381086          220       damage  6.019914e+06
# 21       Vaelyra    1888895568          288       damage  6.558665e+06
# 18          Tawñ    2154438634          285       damage  7.559434e+06
# 15        Shaami    1972587399          254       healer  7.766092e+06
# 11      Mythrose    2166692230          266       healer  8.145460e+06
# 20        Uuglei    1641716733          199       damage  8.249833e+06
# 2          Brian    2359763825          283       damage  8.338388e+06
# 0        Acturus    2386654144          275       healer  8.678742e+06
# 23    Velsummers    2104036015          220       damage  9.563800e+06
# 3     Cagliostro    2600667257          269       damage  9.667908e+06
# 14  Radiantldeal    2589727706          261       healer  9.922328e+06
# ...

# %%
fear_damage.to_csv('guild_awards/argus_fear_damage_ab.csv', encoding='iso-8859-1', index=False)

# %%
sns.distplot(fear_damage.av_count);
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(fear_damage, col='primary_role').map(sns.distplot, "av_count");
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# <a id='argus-rage'></a>
# ### Least Unleashed Rage Damage

# %% [markdown]
# Spell ID: 257911

# %%
rage = wl.damage_taken(api_key, argus_after_break, 257911, 'Unleashed Rage', 2092)
# Out:
# ...
# Player added: Shallowfall
# Player added: Velryssa
# Player added: Brian
# Player added: Cagliostro
# Player added: Metonymy
# Player added: Shaami
# Player added: Radiantldeal
# Player added: Psychodruid
# Player added: Petrol
# Player added: Vaelyra
# Player added: Mythrose
# Player added: Acturus
# Player added: Tawñ
# Player added: Kamer
# Player added: Eleint
# Player added: Ayriea
# Player added: Uuglei
# Player added: Velsummers
# Player added: Illestra
# Player added: Shadowbaine
# Player added: Divanance
# ...
# Player added: Earrl
# Player added: Cagliostro
# Player added: Ayriea
# Player added: Illestra
# Player added: Brian
# Player added: Divanance
# Player added: Uuglei
# Player added: Vaelyra
# Player added: Kamer
# Player added: Shaami
# Player added: Shadowbaine
# Player added: Petrol
# Player added: Radiantldeal
# Player added: Acturus
# Player added: Eleint
# Player added: Tawñ
# Player added: Velsummers
# Player added: Shallowfall
# Player added: Mythrose
# ...

# %%
rage.head()
# Out:
#              log_id  spell_id      spell_name       player  hits  damage_taken
# 0  2cVBtJTgC1KLn7Am    257911  Unleashed Rage  Shallowfall     0     664033042
# 1  2cVBtJTgC1KLn7Am    257911  Unleashed Rage     Velryssa     0      76031931
# 2  2cVBtJTgC1KLn7Am    257911  Unleashed Rage        Brian     0     107433574
# 3  2cVBtJTgC1KLn7Am    257911  Unleashed Rage   Cagliostro     0      74106644
# 4  2cVBtJTgC1KLn7Am    257911  Unleashed Rage     Metonymy     0     133667746

# %%
rage.to_csv('guild_awards/argus_rage_data_ab.csv', encoding='iso-8859-1', index=False)

# %%
rage_damage = la.clean_fight_count(rage, argus_after_break, player_names, 2092, ['damage_taken'])
rage_damage = la.find_count_order(rage_damage, 100, 'damage_taken')
rage_damage
# Out:
#           player  damage_taken  fight_count primary_role      av_count
# 1         Ayriea    1277547165          291       damage  4.390196e+06
# 7          Earrl    1167556651          260         tank  4.490603e+06
# 24       Vaelyra    1366135355          288       damage  4.743526e+06
# 9       Illestra    1397288878          283       healer  4.937417e+06
# 21          Tawñ    1537284860          285       damage  5.393982e+06
# 2          Brian    1557107075          283       damage  5.502145e+06
# 18   Shadowbaine    1637589364          284       damage  5.766160e+06
# 25      Velryssa    1258376277          215       damage  5.852913e+06
# 17        Shaami    1492345439          254       healer  5.875376e+06
# 23        Uuglei    1276233485          199       damage  6.413234e+06
# 3     Cagliostro    1830446071          269       damage  6.804632e+06
# 8         Eleint    1505185200          220       damage  6.841751e+06
# ...

# %%
rage_damage.to_csv('guild_awards/argus_rage_damage_ab.csv', encoding='iso-8859-1', index=False)

# %% [markdown]
# <a id='argus-gaze'></a>
# ### Least Gaze Damage

# %%
gaze = pd.concat([fear, rage])
gaze.head()
# Out:
#              log_id  spell_id     spell_name       player  hits  damage_taken
# 0  2cVBtJTgC1KLn7Am    257930  Crushing Fear     Metonymy     0     140387418
# 1  2cVBtJTgC1KLn7Am    257930  Crushing Fear     Mythrose     0     178359278
# 2  2cVBtJTgC1KLn7Am    257930  Crushing Fear     Velryssa     0      42418318
# 3  2cVBtJTgC1KLn7Am    257930  Crushing Fear  Shadowbaine     0     173418321
# 4  2cVBtJTgC1KLn7Am    257930  Crushing Fear       Ayriea     0     284727678

# %%
gaze.to_csv('guild_awards/argus_gaze_data_ab.csv', encoding='iso-8859-1', index=False)

# %%
gaze_damage = la.clean_fight_count(gaze, argus_after_break, player_names, 2092, ['damage_taken'])
gaze_damage = la.find_count_order(gaze_damage, 100, 'damage_taken')
gaze_damage
# Out:
#           player  damage_taken  fight_count primary_role      av_count
# 7          Earrl    1167556651          260         tank  4.490603e+06
# 24       Vaelyra    3255030923          288       damage  1.130219e+07
# 8         Eleint    2829566286          220       damage  1.286166e+07
# 21          Tawñ    3691723494          285       damage  1.295342e+07
# 15   Psychodruid    3379749635          259       damage  1.304923e+07
# 6      Divanance    3916887108          289         tank  1.355324e+07
# 17        Shaami    3464932838          254       healer  1.364147e+07
# 2          Brian    3916870900          283       damage  1.384053e+07
# 23        Uuglei    2917950218          199       damage  1.466307e+07
# 9       Illestra    4238720868          283       healer  1.497781e+07
# 1         Ayriea    4366686020          291       damage  1.500579e+07
# 13      Mythrose    4226073668          266       healer  1.588749e+07
# ...

# %%
gaze_damage.to_csv('guild_awards/argus_gaze_damage_ab.csv', encoding='iso-8859-1', index=False)

# %%
sns.distplot(gaze_damage.av_count);
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(gaze_damage, col='primary_role').map(sns.distplot, "av_count");
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# <a id='argus-blight'></a>
# ### Least Soulblight/Death Fog Damage

# %% [markdown]
# **Spell IDs**
# - Soulblight: 248396
# - Death Fog: 248167

# %%
soulblight = wl.damage_taken(api_key, argus_after_break, 248396, 'Soulblight', 2092, 5)
# Out:
# ...
# Player added: Tawñ
# Player added: Cagliostro
# Player added: Velsummers
# Player added: Petrol
# Player added: Metonymy
# Player added: Eleint
# Player added: Shadowbaine
# Player added: Kamer
# Player added: Velryssa
# Player added: Illestra
# Player added: Ayriea
# Player added: Shaami
# Player added: Mythrose
# Player added: Uuglei
# Player added: Acturus
# Player added: Vaelyra
# Player added: Radiantldeal
# Player added: Brian
# ...
# Player added: Shadowbaine
# Player added: Uuglei
# Player added: Shaami
# Player added: Metonymy
# Player added: Velsummers
# Player added: Vaelyra
# Player added: Kamer
# Player added: Illestra
# Player added: Tawñ
# Player added: Mythrose
# Player added: Cagliostro
# Player added: Eleint
# Player added: Ayriea
# Player added: Radiantldeal
# Player added: Petrol
# Player added: Brian
# Player added: Acturus
# Player added: Psychodruid
# ...
# Player added: Tawñ
# Player added: Radiantldeal
# Player added: Velsummers
# Player added: Shaami
# ...

# %%
soulblight.head()
# Out:
#              log_id  spell_id  spell_name      player  hits  damage_taken
# 0  2cVBtJTgC1KLn7Am    248396  Soulblight        Tawñ     0     126273727
# 1  2cVBtJTgC1KLn7Am    248396  Soulblight  Cagliostro     0     103027781
# 2  2cVBtJTgC1KLn7Am    248396  Soulblight  Velsummers     0     114196849
# 3  2cVBtJTgC1KLn7Am    248396  Soulblight      Petrol     0      95689789
# 4  2cVBtJTgC1KLn7Am    248396  Soulblight    Metonymy     0     120793963

# %%
deathfog = wl.damage_taken(api_key, argus_after_break, 248167, 'Death Fog', 2092, 5)
# Out:
# ...
# Player added: Eleint
# Player added: Radiantldeal
# Player added: Acturus
# Player added: Divanance
# Player added: Mythrose
# Player added: Shallowfall
# Player added: Cagliostro
# Player added: Ayriea
# Player added: Tawñ
# Player added: Kamer
# Player added: Illestra
# Player added: Metonymy
# Player added: Velryssa
# Player added: Velsummers
# Player added: Uuglei
# Player added: Vaelyra
# Player added: Shadowbaine
# Player added: Brian
# Player added: Shaami
# Player added: Psychodruid
# Player added: Petrol
# ...
# Player added: Shadowbaine
# Player added: Psychodruid
# Player added: Brian
# Player added: Vaelyra
# Player added: Acturus
# Player added: Shaami
# Player added: Illestra
# Player added: Cagliostro
# Player added: Ayriea
# Player added: Tawñ
# Player added: Velsummers
# Player added: Mythrose
# Player added: Petrol
# Player added: Earrl
# Player added: Shallowfall
# Player added: Metonymy
# Player added: Eleint
# Player added: Divanance
# Player added: Kamer
# ...

# %%
deathfog.head()
# Out:
#              log_id  spell_id spell_name        player  hits  damage_taken
# 0  2cVBtJTgC1KLn7Am    248167  Death Fog        Eleint     0      85297086
# 1  2cVBtJTgC1KLn7Am    248167  Death Fog  Radiantldeal     0     151798040
# 2  2cVBtJTgC1KLn7Am    248167  Death Fog       Acturus     0      68477937
# 3  2cVBtJTgC1KLn7Am    248167  Death Fog     Divanance     0     324875969
# 4  2cVBtJTgC1KLn7Am    248167  Death Fog      Mythrose     0      88073729

# %%
blight = pd.concat([soulblight, deathfog])

# %%
blight.to_csv('guild_awards/argus_blightfog_data_ab.csv', encoding='iso-8859-1', index=False)

# %%
blight_damage = la.clean_fight_count(blight, argus_after_break, player_names, 2092, ['damage_taken'])
blight_damage = la.find_count_order(blight_damage, 100, 'damage_taken')
blight_damage
# Out:
#           player  damage_taken  fight_count primary_role      av_count
# 7          Earrl     917505046          260         tank  3.528866e+06
# 15   Psychodruid    1337031547          259       damage  5.162284e+06
# 25      Velryssa    1213686417          215       damage  5.645053e+06
# 8         Eleint    1261611569          220       damage  5.734598e+06
# 13      Mythrose    1604055059          266       healer  6.030282e+06
# 24       Vaelyra    1795872255          288       damage  6.235668e+06
# 3     Cagliostro    1705613473          269       damage  6.340571e+06
# 2          Brian    1929154712          283       damage  6.816801e+06
# 1         Ayriea    2036123816          291       damage  6.996989e+06
# 16  Radiantldeal    1851200284          261       healer  7.092721e+06
# 21          Tawñ    2034346938          285       damage  7.138059e+06
# 9       Illestra    2057177254          283       healer  7.269178e+06
# ...

# %%
blight_damage.to_csv('guild_awards/argus_blightfog_damage_ab.csv', encoding='iso-8859-1', index=False)

# %%
sns.distplot(blight_damage.av_count);
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(blight_damage, col='primary_role').map(sns.distplot, "av_count");
# Out:
# C:\Users\rebecca-barnes\Anaconda3\envs\dand\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# <a id='argus-scythe'></a>
# ### Least Scythe Damage

# %% [markdown]
# **Spell IDS**
# - 258834
# - 251815

# %%
spell_id_258834 = wl.damage_taken(api_key, argus_after_break, 258834, 'Phase 3', 2092)
# Out:
# ...
# Player added: Psychodruid
# Player added: Uuglei
# Player added: Divanance
# Player added: Velryssa
# Player added: Radiantldeal
# Player added: Metonymy
# Player added: Shallowfall
# Player added: Ayriea
# Player added: Kamer
# Player added: Acturus
# Player added: Vaelyra
# ...
# Player added: Ayriea
# Player added: Radiantldeal
# Player added: Uuglei
# Player added: Psychodruid
# Player added: Earrl
# Player added: Divanance
# Player added: Petrol
# Player added: Shallowfall
# Player added: Vaelyra
# Player added: Illestra
# Player added: Mythrose
# Player added: Tawñ
# Player added: Cagliostro
# Player added: Kamer
# ...
# Player added: Mythrose
# Player added: Ayriea
# Player added: Shadowbaine
# Player added: Radiantldeal
# Player added: Vaelyra
# Player added: Cagliostro
# Player added: Illestra
# Player added: Earrl
# Player added: Metonymy
# Player added: Psychodruid
# Player added: Divanance
# Player added: Acturus
# Player added: Petrol
# Player added: Uuglei
# Player added: Eleint
# ...

# %%
spell_id_258834.head()
# Out:
#              log_id  spell_id spell_name        player  hits  damage_taken
# 0  2cVBtJTgC1KLn7Am    258834    Phase 3   Psychodruid     0       6412466
# 1  2cVBtJTgC1KLn7Am    258834    Phase 3        Uuglei     0      36089510
# 2  2cVBtJTgC1KLn7Am    258834    Phase 3     Divanance     0      65447864
# 3  2cVBtJTgC1KLn7Am    258834    Phase 3      Velryssa     0       9080396
# 4  2cVBtJTgC1KLn7Am    258834    Phase 3  Radiantldeal     0      16417521

# %%
spell_id_251815 = wl.damage_taken(api_key, argus_after_break, 251815, 'Phase 2', 2092)
# Out:
# ...
# Player added: Acturus
# Player added: Shallowfall
# Player added: Illestra
# Player added: Velsummers
# Player added: Tawñ
# Player added: Radiantldeal
# Player added: Metonymy
# Player added: Divanance
# Player added: Cagliostro
# Player added: Uuglei
# Player added: Shadowbaine
# Player added: Vaelyra
# Player added: Psychodruid
# Player added: Petrol
# ...
# Player added: Divanance
# Player added: Shadowbaine
# Player added: Brian
# Player added: Velsummers
# Player added: Metonymy
# Player added: Vaelyra
# Player added: Shallowfall
# Player added: Uuglei
# Player added: Ayriea
# Player added: Eleint
# Player added: Shaami
# Player added: Illestra
# Player added: Kamer
# Player added: Cagliostro
# Player added: Radiantldeal
# Player added: Psychodruid
# Player added: Earrl
# ...
# Player added: Petrol
# Player added: Tawñ
# Player added: Vaelyra
# Player added: Eleint
# Player added: Shadowbaine
# Player added: Acturus
# Player added: Divanance
# Player added: Psychodruid
# ...

# %%
spell_id_251815.head()
# Out:
#              log_id  spell_id spell_name       player  hits  damage_taken
# 0  2cVBtJTgC1KLn7Am    251815    Phase 2      Acturus     0       5617392
# 1  2cVBtJTgC1KLn7Am    251815    Phase 2  Shallowfall     0     194368153
# 2  2cVBtJTgC1KLn7Am    251815    Phase 2     Illestra     0       8484277
# 3  2cVBtJTgC1KLn7Am    251815    Phase 2   Velsummers     0      24971653
# 4  2cVBtJTgC1KLn7Am    251815    Phase 2         Tawñ     0      38177954

# %%
scythes = pd.concat([spell_id_251815, spell_id_258834])

# %%
scythes.to_csv('guild_awards/argus_scythe_data_ab.csv', encoding='iso-8859-1', index=False)

# %%
scythes_damage = la.clean_fight_count(scythes, argus_after_break, player_names, 2092, ['damage_taken'])
scythes_damage = la.find_count_order(scythes_damage, 100, 'damage_taken')
scythes_damage
# Out:
#           player  damage_taken  fight_count primary_role      av_count
# 7         Eleint      58911682          220       damage  2.677804e+05
# 2          Brian     157393420          283       damage  5.561605e+05
# 13        Petrol     198781239          288       damage  6.902126e+05
# 1         Ayriea     208557462          291       damage  7.166923e+05
# 0        Acturus     224668681          275       healer  8.169770e+05
# 20          Tawñ     237646896          285       damage  8.338488e+05
# 3     Cagliostro     242597721          269       damage  9.018503e+05
# 16        Shaami     229610109          254       healer  9.039768e+05
# 15  Radiantldeal     272558677          261       healer  1.044286e+06
# 24      Velryssa     238977687          215       damage  1.111524e+06
# 12      Mythrose     297685635          266       healer  1.119119e+06
# 11      Metonymy     342882146          288       damage  1.190563e+06
# ...

# %%
scythes_damage.to_csv('guild_awards/argus_scythe_damage_ab.csv', encoding='iso-8859-1', index=False)

# %% [markdown]
# <a id='argus-orbs'></a>
# ### Most damage done to orbs

# %% [markdown]
# Apocalypsis Module: 130179

# %%
orbs = wl.damage_done(api_key, argus_after_break, 2092)
# Out:
# ...
# Query link: https://www.warcraftlogs.com:443/v1/report/tables/damage-taken/2cVBtJTgC1KLn7Am?end=10230638&hostility=1&by=target&encounter=2092&difficulty=5&api_key=0a60df4bb184d6c614fb96e0126bd407
# Player added: Petrol
# Player added: Psychodruid
# Player added: Illestra
# Player added: Velryssa
# Player added: Kamer
# Player added: Shadowbaine
# Player added: Metonymy
# Player added: Divanance
# Player added: Uuglei
# Player added: Acturus
# Player added: Tawñ
# Player added: Radiantldeal
# Player added: Cagliostro
# Player added: Eleint
# Player added: Vaelyra
# Player added: Ayriea
# Player added: Velsummers
# Player added: Shallowfall
# Player added: Brian
# Player added: Shaami
# Player added: Mythrose
# ...
# Query link: https://www.warcraftlogs.com:443/v1/report/tables/damage-taken/8QYh3aAXpgPLjydJ?end=9509000&hostility=1&by=target&encounter=2092&difficulty=5&api_key=0a60df4bb184d6c614fb96e0126bd407
# Player added: Acturus
# Player added: Uuglei
# Player added: Divanance
# ...

# %%
orbs.head()
# Out:
#              log_id       player   NPC  damage_done
# 0  2cVBtJTgC1KLn7Am       Petrol  True    283604900
# 1  2cVBtJTgC1KLn7Am  Psychodruid  True      4160194
# 2  2cVBtJTgC1KLn7Am     Illestra  True     15372712
# 3  2cVBtJTgC1KLn7Am     Velryssa  True     32123816
# 4  2cVBtJTgC1KLn7Am        Kamer  True      2435489

# %%
orbs.to_csv('guild_awards/argus_orb_data_ab.csv', encoding='iso-8859-1', index=False)

# %%
orb_damage = la.clean_fight_count(orbs, argus_after_break, player_names, 2092, ['damage_done'])
orb_damage = la.find_count_order(orb_damage, 100, 'damage_done', least=False)
orb_damage
# Out:
#           player  damage_done  fight_count primary_role      av_count
# 20   Stradivarus   3681478174          110       damage  3.346798e+07
# 14        Petrol   8971658078          288       damage  3.115159e+07
# 12      Metonymy   8642856799          288       damage  3.000992e+07
# 21          Tawñ   8355255755          285       damage  2.931669e+07
# 26    Velsummers   6407306180          220       damage  2.912412e+07
# 16  Radiantldeal   7463213143          261       healer  2.859469e+07
# 18   Shadowbaine   7139302804          284       damage  2.513839e+07
# 25      Velryssa   4515488323          215       damage  2.100227e+07
# 2          Brian   5936543029          283       damage  2.097718e+07
# 8         Eleint   4150751921          220       damage  1.886705e+07
# 23        Uuglei   2852290524          199       damage  1.433312e+07
# 1         Ayriea   3392212962          291       damage  1.165709e+07
# ...

# %%
orb_damage.to_csv('guild_awards/argus_orb_damage_ab.csv', encoding='iso-8859-1', index=False)

# %% [markdown]
# <a id='overall'></a>
# ## Overall

# %% [markdown]
# <a id='pots'></a>
# ### Buff Pots

# %% [markdown]
# **Spell IDs**
# - Prolonged Power: 229206
# - Potion of Old War: 188028
# - Potion of Deadly Grace: 188027

# %%
prolonged_power = wl.buff_duration(api_key, df, 229206, 'prolonged power')
# Out:
# ...
# Player added: Shallowfall
# Player added: Cagliostro
# Player added: Psychodruid
# Player added: Tawñ
# Player added: Ayriea
# Player added: Tinytiki
# Player added: Petrol
# Player added: Metonymy
# Player added: Divanance
# Player added: Uuglei
# Player added: Earrl
# Player added: Vaelyra
# Player added: Shadowbaine
# Player added: Brian
# Player added: Daffy
# Player added: Radiantldeal
# Player added: Illestra
# ...
# Player added: Shallowfall
# Player added: Thebadlock
# Player added: Znoch
# Player added: Brianmurican
# Player added: Petrol
# Player added: Cinzia
# Player added: Elzam
# Player added: Googboog
# Player added: Earrl
# Player added: Divanance
# Player added: Metonymy
# Player added: Ayriea
# Player added: Psychodruid
# ...
# Player added: Resta
# Player added: Au
# Player added: Radiantldeal
# Player added: Evayne
# Player added: Brian
# Player added: Oakinon
# Player added: Metonymy
# Player added: Future
# Player added: Pulsè
# Player added: Yoked
# Player added: Chomskey
# ...

# %%
prolonged_power.head()
# Out:
#              log_id  spell_id       spell_name       player  duration
# 0  1dApmwBHyQ2vcVTF    229206  prolonged power  Shallowfall   2613338
# 1  1dApmwBHyQ2vcVTF    229206  prolonged power   Cagliostro   1830357
# 2  1dApmwBHyQ2vcVTF    229206  prolonged power  Psychodruid   2373746
# 3  1dApmwBHyQ2vcVTF    229206  prolonged power         Tawñ   2507681
# 4  1dApmwBHyQ2vcVTF    229206  prolonged power       Ayriea   2671834

# %%
prolonged_power.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1551 entries, 0 to 1550
# Data columns (total 5 columns):
# log_id        1551 non-null object
# spell_id      1551 non-null int64
# spell_name    1551 non-null object
# player        1551 non-null object
# duration      1551 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 60.7+ KB

# %%
old_war = wl.buff_duration(api_key, df, 188028, 'old war')
# Out:
# ...
# Player added: Uuglei
# Player added: Stradivarus
# Player added: Vaelyra
# Player added: Cagliostro
# Player added: Velryssa
# ...
# Player added: Kamer
# Player added: Velryssa
# ...
# Player added: Acturus
# Player added: Stradivarus
# Player added: Velryssa
# Player added: Cagliostro
# ...
# Player added: Uuglei
# Player added: Stradivarus
# Player added: Vaelyra
# Player added: Velryssa
# Player added: Cagliostro
# ...
# Player added: Bryiah
# Player added: Stradivarus
# Player added: Velryssa
# ...
# Player added: Stradivarus
# ...
# Player added: Kamer
# Player added: Vaelyra
# Player added: Bryiah
# Player added: Velryssa
# ...
# Player added: Cagliostro
# Player added: Uuglei
# Player added: Kamer
# Player added: Velryssa
# ...
# Player added: Bryiah
# Player added: Velryssa
# Player added: Kamer
# ...
# Player added: Kamer
# Player added: Cagliostro
# Player added: Velryssa
# Player added: Vaelyra
# ...
# Player added: Bryiah
# Player added: Velryssa
# ...
# Player added: Vaelyra
# Player added: Velryssa
# Player added: Kamer
# ...

# %%
old_war.head()
# Out:
#              log_id  spell_id spell_name       player  duration
# 0  1dApmwBHyQ2vcVTF    188028    old war       Uuglei    640546
# 1  1dApmwBHyQ2vcVTF    188028    old war  Stradivarus   1109824
# 2  1dApmwBHyQ2vcVTF    188028    old war      Vaelyra    259983
# 3  1dApmwBHyQ2vcVTF    188028    old war   Cagliostro    247335
# 4  1dApmwBHyQ2vcVTF    188028    old war     Velryssa    591972

# %%
old_war.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 316 entries, 0 to 315
# Data columns (total 5 columns):
# log_id        316 non-null object
# spell_id      316 non-null int64
# spell_name    316 non-null object
# player        316 non-null object
# duration      316 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 12.4+ KB

# %%
one_log = df.query('log_id == "Wc18VDX9wQ62hTjy"')

# %%
deadly_grace = wl.buff_duration(api_key, one_log, 188027, 'deadly grace')
# Out:
# ...
# Player added: Shadowbaine

# %%
deadly_grace.head()
# Out:
#              log_id  spell_id    spell_name       player  duration
# 0  Wc18VDX9wQ62hTjy    188027  deadly grace  Shadowbaine     24918

# %%
pots_df = pd.concat([prolonged_power, old_war, deadly_grace])
pots_df.head()
# Out:
#              log_id  spell_id       spell_name       player  duration
# 0  1dApmwBHyQ2vcVTF    229206  prolonged power  Shallowfall   2613338
# 1  1dApmwBHyQ2vcVTF    229206  prolonged power   Cagliostro   1830357
# 2  1dApmwBHyQ2vcVTF    229206  prolonged power  Psychodruid   2373746
# 3  1dApmwBHyQ2vcVTF    229206  prolonged power         Tawñ   2507681
# 4  1dApmwBHyQ2vcVTF    229206  prolonged power       Ayriea   2671834

# %%
pots_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1868 entries, 0 to 0
# Data columns (total 5 columns):
# log_id        1868 non-null object
# spell_id      1868 non-null int64
# spell_name    1868 non-null object
# player        1868 non-null object
# duration      1868 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 87.6+ KB

# %%
pots_df.to_csv('guild_awards/overall_pot_data.csv', encoding='iso-8859-1', index=False)

# %% [markdown]
# Read in info

# %%
pots_df = pd.read_csv('guild_awards/overall_pot_data.csv', encoding='iso-8859-1')

# %% [markdown]
# Need to create a function to change alt names to final names

# %%
player_names = pd.read_csv('player_list.csv', encoding='iso-8859-1')
player_names.head()
# Out:
#      player primary_role           alt  tier_end  tier_start  start_date
# 0   Vaelyra       damage           NaN      True        True         NaN
# 1  Metonymy       damage           NaN      True        True         NaN
# 2     Brian       damage  Brianmurican      True        True         NaN
# 3    Shaami       healer           NaN      True       False  2018-06-12
# 4    Petrol       damage           NaN      True        True         NaN

# %%
player_names[player_names['alt'] == 'Elzam'].player.iloc[0]
# Out:
# 'Cagliostro'

# %%
pots_copy = player_pots.copy()

# %%
players = player_names['alt'].unique()

# %%
for index, row in pots_copy.iterrows():    
    if row['player'] in players:
        print(index, player_names[player_names['alt'] == player_name].player.iloc[0])
# Out:
# 7 Brian
# 19 Brian
# 20 Brian
# 48 Brian
# 61 Brian

# %%
def change_names(df, player_names):
    players = player_names['alt'].unique()
    for index, row in df.iterrows():
        if row['player'] in players:
            df.at[index, 'player'] = player_names[player_names['alt'] == player_name].player.iloc[0]

# %%
change_names(pots_copy, player_names)
#pots_copy.head()

# %%
pots_copy.nunique()
# Out:
# player        50
# spell_name     3
# duration      63
# dtype: int64

# %% [markdown]
# **Change names and regroup**

# %%
pot_duration = pots_df.copy()
la.change_names(pot_duration, player_names)

# %%
pot_duration.head()
# Out:
#              log_id  spell_id       spell_name       player  duration
# 0  1dApmwBHyQ2vcVTF    229206  prolonged power  Shallowfall   2613338
# 1  1dApmwBHyQ2vcVTF    229206  prolonged power   Cagliostro   1830357
# 2  1dApmwBHyQ2vcVTF    229206  prolonged power  Psychodruid   2373746
# 3  1dApmwBHyQ2vcVTF    229206  prolonged power         Tawñ   2507681
# 4  1dApmwBHyQ2vcVTF    229206  prolonged power       Ayriea   2671834

# %%
new_pots.head(10)
# Out:
#        player       spell_name     duration
# 0     Acturus          old war    3220369.0
# 1       Aqurn  prolonged power    1151747.0
# 2   Arutemisu  prolonged power     416614.0
# 3          Au          old war    3942000.0
# 4          Au  prolonged power   53950237.0
# 5      Ayriea  prolonged power  133517608.0
# 6       Brian          old war     663765.0
# 7       Brian  prolonged power   43975275.6
# 8      Bryiah          old war   11304041.0
# 9  Cagliostro          old war   19741279.0

# %%
new_pots.to_csv('guild_awards/pot_duration.csv', encoding='iso-8859-1', index=False)

# %% [markdown]
# ### Healthstones

# %% [markdown]
# Spell ID: 6262

# %% [markdown]
# #### Query test

# %%
casts = requests.get('https://www.warcraftlogs.com:443/v1/report/tables/casts/vYDj1qQgcXWdmTnF?end=10305202&abilityid=6262&api_key=' + api_key)
details = casts.json()
details
# Out:
# {'entries': [{'name': 'Pulsè',
#    'id': 4,
#    'guid': 139894879,
#    'type': 'Warlock',
#    'icon': 'Warlock-Affliction',
#    'total': 5,
#    'activeTime': 0,
#    'activeTimeReduced': 0,
#    'damageAbilities': [],
#    'targets': [{'name': 'Environment', 'total': 5, 'type': 'NPC'}],
#    'talents': [{'name': 'Writhe in Agony',
#      'guid': 196102,
#      'type': 1,
#      'abilityIcon': 'spell_shadow_curseofsargeras.jpg'},
#     {'name': 'Absolute Corruption',
#      'guid': 196103,
#      'type': 1,
#      'abilityIcon': 'ability_bossmannoroth_empoweredmannorothsgaze.jpg'},
#     {'name': 'Demonic Circle',
#      'guid': 48018,
#      'type': 32,
#      'abilityIcon': 'spell_shadow_demoniccirclesummon.jpg'},
#     {'name': 'Howl of Terror',
#      'guid': 5484,
#      'type': 32,
#      'abilityIcon': 'ability_warlock_howlofterror.jpg'},
#     {'name': 'Soul Harvest',
#      'guid': 196098,
#      'type': 32,
#      'abilityIcon': 'spell_warlock_demonsoul.jpg'},
# ...

# %%
details.keys()
# Out:
# dict_keys(['entries', 'totalTime', 'logVersion'])

# %%
details['entries'][0]['total']
# Out:
# 5

# %% [markdown]
# #### Create function

# %%
def cast_count(api_key, log_df, spell_id, spell_name=None, encounter_number=None):
    df_list = []
    logs = log_df['log_id'].unique()
    for log in logs:
        print('Collecting details for log', log)
        
        # Create link
        end = log_df[log_df['log_id'] == log].pull_end.max()
        if encounter_number is None:
            link = 'https://www.warcraftlogs.com:443/v1/report/tables/casts/' + log + '?end=' + str(end) + \
            '&abilityid=' + str(spell_id) + '&api_key='
        # Check if encounter id in log
        elif encounter_number not in log_df[log_df['log_id'] == log].boss_id.unique():
            continue
        else:
            link = 'https://www.warcraftlogs.com:443/v1/report/tables/casts/' + log + '?end=' + str(end) + \
            '&abilityid=' + str(spell_id) + '&encounter=' + str(encounter_number) + '&api_key='
        
        # Complete query
        event = requests.get(link + api_key)
        details = event.json()
        
        # Get player info
        for player in details['entries']:
            name = player['name']
            print('Player added:', name)
            count = player['total']
            df_list.append({
                'log_id': log, 
                'spell_id': spell_id,
                'spell_name': spell_name,
                'player': name,
                'count': count
            })
    
    # Create dataframe
    df = pd.DataFrame(df_list, columns=['log_id', 'spell_id', 'spell_name', 'player', 'count'])
    # Manage excluded spell info
    if spell_name is None:
        df.drop('spell_name', axis=1, inplace=True)
    
    return df

# %%
casts = cast_count(api_key, test, 6262, 'healthstone')
# Out:
# ...
# Player added: Petrol
# Player added: Èllipses
# Player added: Shadowbaine
# Player added: Mythrose
# Player added: Ayriea
# Player added: Brian
# Player added: Future
# Player added: Undertakerop
# Player added: Daffy
# Player added: Au
# Player added: Velryssa
# Player added: Stradivarus
# Player added: Shallowfall
# Player added: Pulsè
# Player added: Cagliostro
# Player added: Vaelyra

# %%
casts
# Out:
#               log_id  spell_id   spell_name        player  count
# 0   vYDj1qQgcXWdmTnF      6262  healthstone        Petrol      1
# 1   vYDj1qQgcXWdmTnF      6262  healthstone      Èllipses      4
# 2   vYDj1qQgcXWdmTnF      6262  healthstone   Shadowbaine      7
# 3   vYDj1qQgcXWdmTnF      6262  healthstone      Mythrose     10
# 4   vYDj1qQgcXWdmTnF      6262  healthstone        Ayriea     10
# 5   vYDj1qQgcXWdmTnF      6262  healthstone         Brian      9
# 6   vYDj1qQgcXWdmTnF      6262  healthstone        Future      7
# 7   vYDj1qQgcXWdmTnF      6262  healthstone  Undertakerop      2
# 8   vYDj1qQgcXWdmTnF      6262  healthstone         Daffy      5
# 9   vYDj1qQgcXWdmTnF      6262  healthstone            Au     16
# 10  vYDj1qQgcXWdmTnF      6262  healthstone      Velryssa      1
# 11  vYDj1qQgcXWdmTnF      6262  healthstone   Stradivarus      2
# 12  vYDj1qQgcXWdmTnF      6262  healthstone   Shallowfall      4
# ...

# %% [markdown]
# #### Get healthstone casts

# %%
casts = cast_count(api_key, df, 6262, 'healthstone')
# Out:
# ...
# Player added: Brian
# Player added: Metonymy
# Player added: Radiantldeal
# Player added: Stradivarus
# Player added: Mythrose
# Player added: Tinytiki
# Player added: Petrol
# Player added: Shallowfall
# Player added: Tawñ
# Player added: Psychodruid
# Player added: Shadowbaine
# Player added: Cagliostro
# Player added: Daffy
# Player added: Ayriea
# ...
# Player added: Mythrose
# Player added: Znoch
# Player added: Metonymy
# Player added: Vaelyra
# Player added: Kamer
# Player added: Shallowfall
# Player added: Thebadlock
# ...
# Player added: Resta
# Player added: Pulsè
# Player added: Au
# Player added: Divanance
# Player added: Ayriea
# Player added: Shadowbaine
# Player added: Èllipses
# Player added: Duvao
# Player added: Stradivarus
# Player added: Mythrose
# Player added: Acturus
# Player added: Future
# Player added: Delacram
# Player added: Oakinon
# Player added: Yoked
# Player added: Humanraptor
# Player added: Petrol
# Player added: Cagliostro
# Player added: Evayne
# ...

# %%
casts.head()
# Out:
#              log_id  spell_id   spell_name        player  count
# 0  1dApmwBHyQ2vcVTF      6262  healthstone         Brian     11
# 1  1dApmwBHyQ2vcVTF      6262  healthstone      Metonymy      4
# 2  1dApmwBHyQ2vcVTF      6262  healthstone  Radiantldeal      3
# 3  1dApmwBHyQ2vcVTF      6262  healthstone   Stradivarus      9
# 4  1dApmwBHyQ2vcVTF      6262  healthstone      Mythrose      8

# %%
casts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1334 entries, 0 to 1333
# Data columns (total 5 columns):
# log_id        1334 non-null object
# spell_id      1334 non-null int64
# spell_name    1334 non-null object
# player        1334 non-null object
# count         1334 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 52.2+ KB

# %%
casts.nunique()
# Out:
# log_id        93
# spell_id       1
# spell_name     1
# player        48
# count         21
# dtype: int64

# %%
change_names(casts, player_names)

# %%
casts.nunique()
# Out:
# log_id        93
# spell_id       1
# spell_name     1
# player        44
# count         21
# dtype: int64

# %%
healthstone_counts = casts.groupby('player')['count'].sum().reset_index().sort_values('count', ascending=False)
healthstone_counts
# Out:
#           player  count
# 3          Brian    950
# 23      Mythrose    494
# 2         Ayriea    386
# 5     Cagliostro    374
# 1             Au    369
# 32   Shadowbaine    312
# 33   Shallowfall    308
# 34   Stradivarus    263
# 26   Psychodruid    253
# 28  Radiantldeal    244
# 21      Metonymy    233
# 18      Illestra    184
# 35          Tawñ    183
# 19         Kamer    180
# 25        Petrol    178
# 0        Acturus    157
# 7          Daffy    153
# 15        Future    139
# 40    Velsummers    121
# 43      Èllipses    118
# 16      Googboog    101
# 38       Vaelyra    101
# 12         Earrl     97
# 10     Divanance     89
# 13        Eleint     87
# 27         Pulsè     75
# 39      Velryssa     68
# 36      Tinytiki     32
# 6         Cinzia     31
# 31        Shaami     29
# 20       Kyarrix     16
# 37  Undertakerop      7
# 41         Verle      6
# 8       Delacram      5
# 29         Resta      3
# 17   Humanraptor      2
# 4         Bryiah      2
# ...

# %%
healthstone_counts.to_csv('guild_awards/healthstones.csv', encoding='iso-8859-1', index=False)
